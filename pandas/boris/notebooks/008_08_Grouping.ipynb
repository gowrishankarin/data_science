# %%
import pandas as pd

# %%
fortune = pd.read_csv("../data/fortune1000.csv", index_col="Rank")
sectors = fortune.groupby("Sector")
fortune.head()
# Out:
#                  Company       Sector  \
# Rank
# 1                Walmart    Retailing
# 2            Exxon Mobil       Energy
# 3                  Apple   Technology
# 4     Berkshire Hathaway   Financials
# 5               McKesson  Health Care
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600
# 3       53394     110000
# 4       24083     331000
# 5        1476      70400

# %%
type(sectors)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %% [markdown]
# ### The .groupby() Method

# %%
len(sectors)
# Out:
# 21

# %%
fortune["Sector"].nunique()
# Out:
# 21

# %%
sectors.size()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
fortune["Sector"].value_counts()
# Out:
# Financials                      139
# Energy                          122
# Technology                      102
# Retailing                        80
# Health Care                      75
# Business Services                51
# Industrials                      46
# Materials                        43
# Food, Beverages & Tobacco        43
# Wholesalers                      40
# Transportation                   36
# Chemicals                        30
# Household Products               28
# Engineering & Construction       26
# Media                            25
# Hotels, Resturants & Leisure     25
# Motor Vehicles & Parts           24
# Aerospace & Defense              20
# Telecommunications               15
# Food and Drug Stores             15
# Apparel                          15
# Name: Sector, dtype: int64

# %%
sectors.first()
# Out:
#                                              Company  \
# Sector
# Aerospace & Defense                           Boeing
# Apparel                                         Nike
# Business Services                      ManpowerGroup
# Chemicals                               Dow Chemical
# Energy                                   Exxon Mobil
# Engineering & Construction                     Fluor
# Financials                        Berkshire Hathaway
# Food and Drug Stores                      CVS Health
# Food, Beverages & Tobacco     Archer Daniels Midland
# Health Care                                 McKesson
# Hotels, Resturants & Leisure              McDonald’s
# Household Products                  Procter & Gamble
# Industrials                         General Electric
# Materials                                      Alcoa
# Media                                         Disney
# Motor Vehicles & Parts                General Motors
# ...

# %%
type(sectors.first())
# Out:
# pandas.core.frame.DataFrame

# %%
fortune.loc[24]
# Out:
# Company                     Boeing
# Sector         Aerospace & Defense
# Industry     Aerospace and Defense
# Location               Chicago, IL
# Revenue                      96114
# Profits                       5176
# Employees                   161400
# Name: 24, dtype: object

# %%
sectors.groups
# Out:
# {'Aerospace & Defense': Int64Index([ 24,  45,  60,  88, 118, 120, 209, 245, 282, 378, 389, 490, 560,
#              605, 785, 788, 836, 903, 958, 987],
#             dtype='int64', name='Rank'),
#  'Apparel': Int64Index([91, 231, 340, 354, 448, 547, 575, 597, 683, 695, 726, 794, 877,
#              882, 917],
#             dtype='int64', name='Rank'),
#  'Business Services': Int64Index([144, 186, 199, 204, 221, 248, 249, 294, 307, 312, 355, 392, 404,
#              440, 467, 468, 481, 485, 492, 503, 545, 626, 635, 652, 677, 694,
#              714, 729, 734, 735, 737, 744, 767, 776, 777, 783, 791, 792, 796,
#              801, 803, 816, 819, 820, 869, 870, 886, 939, 951, 952, 993],
#             dtype='int64', name='Rank'),
#  'Chemicals': Int64Index([ 56, 101, 182, 189, 206, 253, 262, 277, 288, 296, 316, 538, 549,
#              555, 566, 580, 613, 624, 654, 668, 717, 720, 724, 758, 761, 829,
#              865, 898, 934, 949],
#             dtype='int64', name='Rank'),
# ...

# %% [markdown]
# ### Retrieve a Group with the .get_group() Method

# %%
sectors.get_group("Energy").head()
# Out:
#                  Company            Industry         Location  Revenue  \
# Rank
# 2            Exxon Mobil  Petroleum Refining       Irving, TX   246204
# 14               Chevron  Petroleum Refining    San Ramon, CA   131118
# 30           Phillips 66  Petroleum Refining      Houston, TX    87169
# 32         Valero Energy  Petroleum Refining  San Antonio, TX    81824
# 42    Marathon Petroleum  Petroleum Refining      Findlay, OH    64566
#
#       Profits  Employees
# Rank
# 2       16150      75600
# 14       4587      61500
# 30       4227      14000
# 32       3990      10103
# 42       2852      45440

# %%
fortune[fortune["Sector"] == "Energy"]
# Out:
#                            Company  Sector                         Industry  \
# Rank
# 2                      Exxon Mobil  Energy               Petroleum Refining
# 14                         Chevron  Energy               Petroleum Refining
# 30                     Phillips 66  Energy               Petroleum Refining
# 32                   Valero Energy  Energy               Petroleum Refining
# 42              Marathon Petroleum  Energy               Petroleum Refining
# 65          Energy Transfer Equity  Energy                        Pipelines
# 90                  ConocoPhillips  Energy     Mining, Crude-Oil Production
# 95                          Exelon  Energy      Utilities: Gas and Electric
# 98                          Tesoro  Energy               Petroleum Refining
# 104   Enterprise Products Partners  Energy                        Pipelines
# 115                    Duke Energy  Energy      Utilities: Gas and Electric
# ...

# %% [markdown]
# ### Methods on the Groupby Object and DataFrame Columns

# %%
sectors.min()
sectors.max()
# Out:
#                                              Company  \
# Sector
# Aerospace & Defense                         Woodward
# Apparel                         Wolverine World Wide
# Business Services                      Western Union
# Chemicals                          Westlake Chemical
# Energy                                   Xcel Energy
# Engineering & Construction              Tutor Perini
# Financials                            Zions Bancorp.
# Food and Drug Stores              Whole Foods Market
# Food, Beverages & Tobacco            WhiteWave Foods
# Health Care                          inVentiv Health
# Hotels, Resturants & Leisure              Yum Brands
# Household Products                     Vista Outdoor
# Industrials                       Zebra Technologies
# Materials                     Worthington Industries
# Media                                    iHeartMedia
# Motor Vehicles & Parts               Wabash National
# ...

# %%
sectors.sum()
# Out:
#                               Revenue  Profits  Employees
# Sector
# Aerospace & Defense            357940    28742     968057
# Apparel                         95968     8236     346397
# Business Services              272195    28227    1361050
# Chemicals                      243897    22628     463651
# Energy                        1517809   -73447    1188927
# Engineering & Construction     153983     5304     406708
# Financials                    2217159   260209    3359948
# Food and Drug Stores           483769    16759    1395398
# Food, Beverages & Tobacco      555967    51417    1211632
# Health Care                   1614707   106114    2678289
# Hotels, Resturants & Leisure   169546    20697    2484245
# Household Products             234737    14428     646038
# Industrials                    497581    20764    1545229
# Materials                      259145     4428     638123
# Media                          220764    24347     550314
# ...

# %%
sectors.mean()
# Out:
#                                    Revenue      Profits     Employees
# Sector
# Aerospace & Defense           17897.000000  1437.100000  48402.850000
# Apparel                        6397.866667   549.066667  23093.133333
# Business Services              5337.156863   553.470588  26687.254902
# Chemicals                      8129.900000   754.266667  15455.033333
# Energy                        12441.057377  -602.024590   9745.303279
# Engineering & Construction     5922.423077   204.000000  15642.615385
# Financials                    15950.784173  1872.007194  24172.287770
# Food and Drug Stores          32251.266667  1117.266667  93026.533333
# Food, Beverages & Tobacco     12929.465116  1195.744186  28177.488372
# Health Care                   21529.426667  1414.853333  35710.520000
# Hotels, Resturants & Leisure   6781.840000   827.880000  99369.800000
# Household Products             8383.464286   515.285714  23072.785714
# ...

# %%
sectors["Revenue"].sum()
# Out:
# Sector
# Aerospace & Defense              357940
# Apparel                           95968
# Business Services                272195
# Chemicals                        243897
# Energy                          1517809
# Engineering & Construction       153983
# Financials                      2217159
# Food and Drug Stores             483769
# Food, Beverages & Tobacco        555967
# Health Care                     1614707
# Hotels, Resturants & Leisure     169546
# Household Products               234737
# Industrials                      497581
# Materials                        259145
# Media                            220764
# Motor Vehicles & Parts           482540
# Retailing                       1465076
# Technology                      1377600
# Telecommunications               461834
# Transportation                   408508
# Wholesalers                      444800
# Name: Revenue, dtype: int64

# %%
sectors[["Revenue", "Employees"]].sum()
# Out:
#                               Revenue  Employees
# Sector
# Aerospace & Defense            357940     968057
# Apparel                         95968     346397
# Business Services              272195    1361050
# Chemicals                      243897     463651
# Energy                        1517809    1188927
# Engineering & Construction     153983     406708
# Financials                    2217159    3359948
# Food and Drug Stores           483769    1395398
# Food, Beverages & Tobacco      555967    1211632
# Health Care                   1614707    2678289
# Hotels, Resturants & Leisure   169546    2484245
# Household Products             234737     646038
# Industrials                    497581    1545229
# Materials                      259145     638123
# Media                          220764     550314
# Motor Vehicles & Parts         482540    1082560
# Retailing                     1465076    6227629
# Technology                    1377600    3578949
# ...

# %%
sectors[["Revenue", "Employees"]].agg(["sum", "mean"])
# Out:
#                               Revenue               Employees
#                                   sum          mean       sum          mean
# Sector
# Aerospace & Defense            357940  17897.000000    968057  48402.850000
# Apparel                         95968   6397.866667    346397  23093.133333
# Business Services              272195   5337.156863   1361050  26687.254902
# Chemicals                      243897   8129.900000    463651  15455.033333
# Energy                        1517809  12441.057377   1188927   9745.303279
# Engineering & Construction     153983   5922.423077    406708  15642.615385
# Financials                    2217159  15950.784173   3359948  24172.287770
# Food and Drug Stores           483769  32251.266667   1395398  93026.533333
# Food, Beverages & Tobacco      555967  12929.465116   1211632  28177.488372
# Health Care                   1614707  21529.426667   2678289  35710.520000
# ...

# %% [markdown]
# ### Grouping by Multiple Columns

# %%
sectors = fortune.groupby(["Sector", "Industry"])

# %%
sectors.size()
# Out:
# Sector                      Industry
# Aerospace & Defense         Aerospace and Defense                             20
# Apparel                     Apparel                                           15
# Business Services           Advertising, marketing                             2
#                             Diversified Outsourcing Services                  14
#                             Education                                          3
#                             Financial Data Services                           19
#                             Miscellaneous                                      3
#                             Temporary Help                                     5
#                             Waste Management                                   5
# Chemicals                   Chemicals                                         30
# Energy                      Energy                                            14
# ...

# %%
len(sectors)
# Out:
# 79

# %%
sectors.sum()
# Out:
#                                                                            Revenue  \
# Sector                     Industry
# Aerospace & Defense        Aerospace and Defense                            357940
# Apparel                    Apparel                                           95968
# Business Services          Advertising, marketing                            22748
#                            Diversified Outsourcing Services                  64829
#                            Education                                          7485
#                            Financial Data Services                          100778
#                            Miscellaneous                                     11185
#                            Temporary Help                                    34716
#                            Waste Management                                  30454
# Chemicals                  Chemicals                                        243897
# ...

# %%
sectors["Revenue"].sum()
# Out:
# Sector                      Industry
# Aerospace & Defense         Aerospace and Defense                             357940
# Apparel                     Apparel                                            95968
# Business Services           Advertising, marketing                             22748
#                             Diversified Outsourcing Services                   64829
#                             Education                                           7485
#                             Financial Data Services                           100778
#                             Miscellaneous                                      11185
#                             Temporary Help                                     34716
#                             Waste Management                                   30454
# Chemicals                   Chemicals                                         243897
# Energy                      Energy                                             67749
# ...

# %%
sectors["Employees"].mean()
# Out:
# Sector                      Industry
# Aerospace & Defense         Aerospace and Defense                              48402.850000
# Apparel                     Apparel                                            23093.133333
# Business Services           Advertising, marketing                             62050.000000
#                             Diversified Outsourcing Services                   50595.000000
#                             Education                                          15585.000000
#                             Financial Data Services                            13943.473684
#                             Miscellaneous                                      12573.333333
#                             Temporary Help                                     12004.000000
#                             Waste Management                                   23839.800000
# Chemicals                   Chemicals                                          15455.033333
# ...

# %% [markdown]
# ### The .agg() Method

# %%
sectors[["Profits", "Employees"]].agg(["mean", "sum"])
# Out:
#                                                                                Profits  \
#                                                                                   mean
# Sector                     Industry
# Aerospace & Defense        Aerospace and Defense                           1437.100000
# Apparel                    Apparel                                          549.066667
# Business Services          Advertising, marketing                           774.500000
#                            Diversified Outsourcing Services                 307.500000
#                            Education                                         23.000000
#                            Financial Data Services                          918.736842
#                            Miscellaneous                                    710.000000
#                            Temporary Help                                   200.000000
# ...

# %%
sectors.agg({"Revenue": "mean", "Profits":"sum"})
# Out:
#                                                                                 Revenue  \
# Sector                     Industry
# Aerospace & Defense        Aerospace and Defense                           17897.000000
# Apparel                    Apparel                                          6397.866667
# Business Services          Advertising, marketing                          11374.000000
#                            Diversified Outsourcing Services                 4630.642857
#                            Education                                        2495.000000
#                            Financial Data Services                          5304.105263
#                            Miscellaneous                                    3728.333333
#                            Temporary Help                                   6943.200000
#                            Waste Management                                 6090.800000
# ...

# %%
sectors.agg(["size", "sum", "mean"])
# Out:
#                                                                           Revenue  \
#                                                                              size
# Sector                     Industry
# Aerospace & Defense        Aerospace and Defense                               20
# Apparel                    Apparel                                             15
# Business Services          Advertising, marketing                               2
#                            Diversified Outsourcing Services                    14
#                            Education                                            3
#                            Financial Data Services                             19
#                            Miscellaneous                                        3
#                            Temporary Help                                       5
#                            Waste Management                                     5
# ...

# %% [markdown]
# ### Iterating through Groups

# %%
sectors["Profits"].max()
# Out:
# Sector                      Industry
# Aerospace & Defense         Aerospace and Defense                              7608
# Apparel                     Apparel                                            3273
# Business Services           Advertising, marketing                             1094
#                             Diversified Outsourcing Services                   1453
#                             Education                                           140
#                             Financial Data Services                            6328
#                             Miscellaneous                                      1311
#                             Temporary Help                                      419
#                             Waste Management                                    753
# Chemicals                   Chemicals                                          7685
# Energy                      Energy                                              546
# ...

# %%
df = pd.DataFrame(columns=fortune.columns)
df
# Out:
# Empty DataFrame
# Columns: [Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
fortune = pd.read_csv("../data/fortune1000.csv", index_col="Rank")
sectors = fortune.groupby("Sector")
fortune.head()
# Out:
#                  Company       Sector  \
# Rank
# 1                Walmart    Retailing
# 2            Exxon Mobil       Energy
# 3                  Apple   Technology
# 4     Berkshire Hathaway   Financials
# 5               McKesson  Health Care
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600
# 3       53394     110000
# 4       24083     331000
# 5        1476      70400

# %%
for sector, data in sectors:
    highest_revenue_company_in_group = data.nlargest(1, "Revenue")
    df = df.append(highest_revenue_company_in_group)

# %%
df
# Out:
#                        Company                        Sector  \
# 24                      Boeing           Aerospace & Defense
# 91                        Nike                       Apparel
# 186              Omnicom Group             Business Services
# 199                    Aramark             Business Services
# 737            Graham Holdings             Business Services
# 204                       Visa             Business Services
# 440             United Rentals             Business Services
# 144              ManpowerGroup             Business Services
# 221           Waste Management             Business Services
# 56                Dow Chemical                     Chemicals
# 193                 NRG Energy                        Energy
# 90              ConocoPhillips                        Energy
# 696       American Water Works                        Energy
# 117                Halliburton                        Energy
# ...

# %%
cities = fortune.groupby("Location")
df = pd.DataFrame(columns=fortune.columns)
df
# Out:
# Empty DataFrame
# Columns: [Company, Sector, Industry, Location, Revenue, Profits, Employees]
# Index: []

# %%
for city, data in cities:
    highest_revenue_in_city = data.nlargest(1, "Revenue")
    df = df.append(highest_revenue_in_city)

# %%
df
# Out:
#                                   Company                        Sector  \
# 138                   Abbott Laboratories                   Health Care
# 169                Goodyear Tire & Rubber        Motor Vehicles & Parts
# 288              Air Products & Chemicals                     Chemicals
# 830                 Benchmark Electronics                    Technology
# 374                Casey’s General Stores                     Retailing
# 915                        Domino’s Pizza  Hotels, Resturants & Leisure
# 596                                Colfax                   Industrials
# 215                          Land O’Lakes     Food, Beverages & Tobacco
# 190                                   AES                        Energy
# 31                                    IBM                    Technology
# 28                             Home Depot                     Retailing
# 310                               Autoliv        Motor Vehicles & Parts
# ...
