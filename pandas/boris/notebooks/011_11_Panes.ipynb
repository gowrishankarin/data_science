# %%
import pandas as pd
from pandas_datareader import data

# %%
companies = ["MSFT", "GOOG", "YHOO", "AMZN"]
p = data.DataReader(companies, data_source="yahoo", start="2010-01-01", end="2016-12-31")
type(p)
# Out:
# pandas.core.frame.DataFrame

# %%
p.head()
# Out:
# Attributes        High                                     Low              \
# Symbols           AMZN        GOOG       MSFT YHOO        AMZN        GOOG
# Date
# 2009-12-31  137.279999  310.679321  30.990000  NaN  134.520004  307.986847
# 2010-01-04  136.610001  312.721039  31.100000  NaN  133.139999  310.103088
# 2010-01-05  135.479996  311.891449  31.100000  NaN  131.809998  308.761810
# 2010-01-06  134.729996  310.907837  31.080000  NaN  131.649994  301.220856
# 2010-01-07  132.320007  303.029083  30.700001  NaN  128.800003  294.410156
#
# Attributes                        Open              ...      Close       \
# Symbols          MSFT YHOO        AMZN        GOOG  ...       MSFT YHOO
# Date                                                ...
# 2009-12-31  30.480000  NaN  137.089996  310.356445  ...  30.480000  NaN
# 2010-01-04  30.590000  NaN  136.250000  311.449310  ...  30.950001  NaN
# 2010-01-05  30.639999  NaN  133.429993  311.563568  ...  30.959999  NaN
# ...

# %%
p["Open"].head()
# Out:
# Symbols           AMZN        GOOG       MSFT  YHOO
# Date
# 2009-12-31  137.089996  310.356445  30.980000   NaN
# 2010-01-04  136.250000  311.449310  30.620001   NaN
# 2010-01-05  133.429993  311.563568  30.850000   NaN
# 2010-01-06  134.600006  310.907837  30.879999   NaN
# 2010-01-07  132.009995  302.731018  30.629999   NaN

# %%
p["Volume"].head()
# Out:
# Symbols           AMZN        GOOG        MSFT  YHOO
# Date
# 2009-12-31   4523000.0   2455400.0  31929700.0   NaN
# 2010-01-04   7599900.0   3937800.0  38409100.0   NaN
# 2010-01-05   8851900.0   6048500.0  49749600.0   NaN
# 2010-01-06   7178800.0   8009000.0  58182400.0   NaN
# 2010-01-07  11030200.0  12912000.0  50559700.0   NaN

# %% [markdown]
# ### Extracting with .loc and iloc

# %%
p.transpose()
# Out:
# Date                  2009-12-31    2010-01-04    2010-01-05    2010-01-06  \
# Attributes Symbols
# High       AMZN     1.372800e+02  1.366100e+02  1.354800e+02  1.347300e+02
#            GOOG     3.106793e+02  3.127210e+02  3.118914e+02  3.109078e+02
#            MSFT     3.099000e+01  3.110000e+01  3.110000e+01  3.108000e+01
#            YHOO              NaN           NaN           NaN           NaN
# Low        AMZN     1.345200e+02  1.331400e+02  1.318100e+02  1.316500e+02
#            GOOG     3.079868e+02  3.101031e+02  3.087618e+02  3.012209e+02
#            MSFT     3.048000e+01  3.059000e+01  3.064000e+01  3.052000e+01
#            YHOO              NaN           NaN           NaN           NaN
# Open       AMZN     1.370900e+02  1.362500e+02  1.334300e+02  1.346000e+02
#            GOOG     3.103564e+02  3.114493e+02  3.115636e+02  3.109078e+02
#            MSFT     3.098000e+01  3.062000e+01  3.085000e+01  3.088000e+01
# ...
