# %%
import matplotlib.pylab as plt
import seaborn as sns
sns.despine
# Out:
# <function seaborn.utils.despine>

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.normalization import BatchNormalization
from keras.layers import Merge, LeakyReLU
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, CSVLogger, EarlyStopping
from keras.optimizers import RMSprop, Adam, SGD, Nadam
from keras.layers.advanced_activations import *
from keras.layers import Convolution1D, MaxPooling1D, AtrousConvolution1D
from keras.layers.recurrent import LSTM, GRU
from keras import regularizers
# Out:
# /anaconda3/envs/dlcv/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from preprocessing import shuffle_in_unison, create_Xt_Yt
# Out:
# [NbConvertApp] Converting notebook 001_Preprocessing.ipynb to python
# [NbConvertApp] Writing 3251 bytes to 001_Preprocessing.py

# %%
import pandas as pd

data = pd.read_csv("../datasets/apple/AAPL.csv")[::-1]
data.head()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 3088  2017-04-07  143.729996  144.179993  143.270004  143.339996  140.565704
# 3087  2017-04-06  144.289993  144.520004  143.449997  143.660004  140.879517
# 3086  2017-04-05  144.220001  145.460007  143.809998  144.020004  141.232559
# 3085  2017-04-04  143.250000  144.889999  143.169998  144.770004  141.968033
# 3084  2017-04-03  143.710007  144.119995  143.050003  143.699997  140.918762
#
#         Volume
# 3088  16672200
# 3087  21149000
# 3086  27717900
# 3085  19891400
# 3084  19985700

# %%
data = data.loc[:, 'Adj Close'].tolist()
plt.plot(data)
plt.show()

# %%
WINDOW = 30
EMB_SIZE = 1
STEP = 1
FORECAST = 5

# %%
# Create time window
X, Y = [], []
for i in range(0, len(data), STEP):
    try:
        x_i = data[i:i + WINDOW]
        y_i = data[i + WINDOW + FORECAST]

        last_close = x_i[WINDOW - 1]
        next_close = y_i

        if last_close < next_close:
            y_i = [1, 0]
        else:
            y_i = [0, 1]
    except Exception as e:
        print(e)
        break
        
    X.append(x_i)
    Y.append(y_i)
# Out:
# list index out of range

# %%
print(len(X))
print(len(X))
# Out:
# 3054
# 3054

# %%
import numpy as np
X = [(np.array(x) - np.mean(x)) / np.std(x) for x in X]
X, Y = np.array(X), np.array(Y)

X_train, X_test, Y_train, Y_test = create_Xt_Yt(X, Y)

# %%
print(X.shape)
print(Y.shape)
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (3054, 30)
# (3054, 2)
# (2443, 30)
# (2443, 2)
# (611, 30)
# (611, 2)

# %%
model = Sequential()
model.add(Dense(64, input_dim=30, activity_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Dropout(0.5))
model.add(Dense(16, activity_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Dense(2))
model.add(Activation('softmax'))

opt = Nadam(lr=0.001)

reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.9, patience=25, min_lr=0.000001, verbose=1)
checkpointer = ModelCheckpoint('output/test_cls.hdf5', verbose=1, save_best_only=True)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
H = model.fit(X_train, Y_train, epochs=150, batch_size=128, verbose=1,
    validation_data=(X_test, Y_test), callbacks=[reduce_lr, checkpointer], shuffle=True)
# Out:
# Train on 2443 samples, validate on 611 samples
# Epoch 1/150
# 2443/2443 [==============================] - 1s 210us/step - loss: 70.4964 - acc: 0.4265 - val_loss: 36.0689 - val_acc: 0.3797
#
# Epoch 00001: val_loss improved from inf to 36.06892, saving model to output/test_cls.hdf5
# Epoch 2/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 47.5372 - acc: 0.4220 - val_loss: 22.4516 - val_acc: 0.4550
#
# Epoch 00002: val_loss improved from 36.06892 to 22.45164, saving model to output/test_cls.hdf5
# Epoch 3/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 35.0765 - acc: 0.4339 - val_loss: 16.1821 - val_acc: 0.5221
#
# Epoch 00003: val_loss improved from 22.45164 to 16.18214, saving model to output/test_cls.hdf5
# Epoch 4/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 27.6197 - acc: 0.4470 - val_loss: 12.7598 - val_acc: 0.5548
#
# Epoch 00004: val_loss improved from 16.18214 to 12.75980, saving model to output/test_cls.hdf5
# Epoch 5/150
# 2443/2443 [==============================] - 0s 84us/step - loss: 22.7478 - acc: 0.4556 - val_loss: 10.5844 - val_acc: 0.5957
#
# Epoch 00005: val_loss improved from 12.75980 to 10.58442, saving model to output/test_cls.hdf5
# Epoch 6/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 19.3700 - acc: 0.4756 - val_loss: 9.0951 - val_acc: 0.6007
#
# Epoch 00006: val_loss improved from 10.58442 to 9.09510, saving model to output/test_cls.hdf5
# Epoch 7/150
# 2443/2443 [==============================] - 0s 90us/step - loss: 16.8128 - acc: 0.5031 - val_loss: 7.9918 - val_acc: 0.6023
#
# Epoch 00007: val_loss improved from 9.09510 to 7.99183, saving model to output/test_cls.hdf5
# Epoch 8/150
# 2443/2443 [==============================] - 0s 86us/step - loss: 14.4777 - acc: 0.4998 - val_loss: 7.1079 - val_acc: 0.6039
#
# Epoch 00008: val_loss improved from 7.99183 to 7.10787, saving model to output/test_cls.hdf5
# Epoch 9/150
# 2443/2443 [==============================] - 0s 85us/step - loss: 12.7921 - acc: 0.5031 - val_loss: 6.3864 - val_acc: 0.6023
#
# Epoch 00009: val_loss improved from 7.10787 to 6.38642, saving model to output/test_cls.hdf5
# Epoch 10/150
# 2443/2443 [==============================] - 0s 85us/step - loss: 11.3344 - acc: 0.5133 - val_loss: 5.7823 - val_acc: 0.6088
#
# Epoch 00010: val_loss improved from 6.38642 to 5.78230, saving model to output/test_cls.hdf5
# Epoch 11/150
# 2443/2443 [==============================] - 0s 87us/step - loss: 10.0813 - acc: 0.5289 - val_loss: 5.2672 - val_acc: 0.6088
#
# Epoch 00011: val_loss improved from 5.78230 to 5.26717, saving model to output/test_cls.hdf5
# Epoch 12/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 9.0925 - acc: 0.5231 - val_loss: 4.8485 - val_acc: 0.6088
#
# Epoch 00012: val_loss improved from 5.26717 to 4.84846, saving model to output/test_cls.hdf5
# Epoch 13/150
# 2443/2443 [==============================] - 0s 87us/step - loss: 8.1411 - acc: 0.5108 - val_loss: 4.4782 - val_acc: 0.6121
#
# Epoch 00013: val_loss improved from 4.84846 to 4.47822, saving model to output/test_cls.hdf5
# Epoch 14/150
# 2443/2443 [==============================] - 0s 90us/step - loss: 7.3234 - acc: 0.5350 - val_loss: 4.1551 - val_acc: 0.6121
#
# Epoch 00014: val_loss improved from 4.47822 to 4.15509, saving model to output/test_cls.hdf5
# Epoch 15/150
# 2443/2443 [==============================] - 0s 86us/step - loss: 6.6560 - acc: 0.5350 - val_loss: 3.8837 - val_acc: 0.6105
#
# Epoch 00015: val_loss improved from 4.15509 to 3.88366, saving model to output/test_cls.hdf5
# Epoch 16/150
# 2443/2443 [==============================] - 0s 89us/step - loss: 6.0860 - acc: 0.5542 - val_loss: 3.6398 - val_acc: 0.6105
#
# Epoch 00016: val_loss improved from 3.88366 to 3.63980, saving model to output/test_cls.hdf5
# Epoch 17/150
# 2443/2443 [==============================] - 0s 86us/step - loss: 5.5719 - acc: 0.5313 - val_loss: 3.4103 - val_acc: 0.6088
#
# Epoch 00017: val_loss improved from 3.63980 to 3.41031, saving model to output/test_cls.hdf5
# Epoch 18/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 5.1409 - acc: 0.5334 - val_loss: 3.2182 - val_acc: 0.6088
#
# Epoch 00018: val_loss improved from 3.41031 to 3.21822, saving model to output/test_cls.hdf5
# Epoch 19/150
# 2443/2443 [==============================] - 0s 93us/step - loss: 4.7221 - acc: 0.5436 - val_loss: 3.0358 - val_acc: 0.6105
#
# Epoch 00019: val_loss improved from 3.21822 to 3.03581, saving model to output/test_cls.hdf5
# Epoch 20/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 4.3809 - acc: 0.5538 - val_loss: 2.8763 - val_acc: 0.6105
#
# Epoch 00020: val_loss improved from 3.03581 to 2.87625, saving model to output/test_cls.hdf5
# Epoch 21/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 4.0566 - acc: 0.5542 - val_loss: 2.7334 - val_acc: 0.6105
#
# Epoch 00021: val_loss improved from 2.87625 to 2.73339, saving model to output/test_cls.hdf5
# Epoch 22/150
# 2443/2443 [==============================] - 0s 87us/step - loss: 3.7897 - acc: 0.5567 - val_loss: 2.5988 - val_acc: 0.6105
#
# Epoch 00022: val_loss improved from 2.73339 to 2.59877, saving model to output/test_cls.hdf5
# Epoch 23/150
# 2443/2443 [==============================] - 0s 87us/step - loss: 3.5426 - acc: 0.5526 - val_loss: 2.4826 - val_acc: 0.6105
#
# Epoch 00023: val_loss improved from 2.59877 to 2.48256, saving model to output/test_cls.hdf5
# Epoch 24/150
# 2443/2443 [==============================] - 0s 89us/step - loss: 3.3205 - acc: 0.5612 - val_loss: 2.3644 - val_acc: 0.6105
#
# Epoch 00024: val_loss improved from 2.48256 to 2.36443, saving model to output/test_cls.hdf5
# Epoch 25/150
# 2443/2443 [==============================] - 0s 89us/step - loss: 3.1215 - acc: 0.5559 - val_loss: 2.2637 - val_acc: 0.6105
#
# Epoch 00025: val_loss improved from 2.36443 to 2.26375, saving model to output/test_cls.hdf5
# Epoch 26/150
# 2443/2443 [==============================] - 0s 91us/step - loss: 2.9333 - acc: 0.5567 - val_loss: 2.1691 - val_acc: 0.6105
#
# Epoch 00026: val_loss improved from 2.26375 to 2.16914, saving model to output/test_cls.hdf5
# Epoch 27/150
# 2443/2443 [==============================] - 0s 89us/step - loss: 2.7630 - acc: 0.5710 - val_loss: 2.0794 - val_acc: 0.6105
#
# Epoch 00027: val_loss improved from 2.16914 to 2.07944, saving model to output/test_cls.hdf5
# Epoch 28/150
# 2443/2443 [==============================] - 0s 94us/step - loss: 2.6101 - acc: 0.5677 - val_loss: 1.9966 - val_acc: 0.6105
#
# Epoch 00028: val_loss improved from 2.07944 to 1.99656, saving model to output/test_cls.hdf5
# Epoch 29/150
# 2443/2443 [==============================] - 0s 85us/step - loss: 2.4566 - acc: 0.5763 - val_loss: 1.9182 - val_acc: 0.6105
#
# Epoch 00029: val_loss improved from 1.99656 to 1.91818, saving model to output/test_cls.hdf5
# Epoch 30/150
# 2443/2443 [==============================] - 0s 89us/step - loss: 2.3520 - acc: 0.5673 - val_loss: 1.8464 - val_acc: 0.6105
#
# Epoch 00030: val_loss improved from 1.91818 to 1.84637, saving model to output/test_cls.hdf5
# Epoch 31/150
# 2443/2443 [==============================] - 0s 87us/step - loss: 2.2363 - acc: 0.5743 - val_loss: 1.7788 - val_acc: 0.6105
#
# Epoch 00031: val_loss improved from 1.84637 to 1.77879, saving model to output/test_cls.hdf5
# Epoch 32/150
# 2443/2443 [==============================] - 0s 89us/step - loss: 2.1250 - acc: 0.5784 - val_loss: 1.7176 - val_acc: 0.6105
#
# Epoch 00032: val_loss improved from 1.77879 to 1.71758, saving model to output/test_cls.hdf5
# Epoch 33/150
# 2443/2443 [==============================] - 0s 90us/step - loss: 2.0341 - acc: 0.5698 - val_loss: 1.6587 - val_acc: 0.6105
#
# Epoch 00033: val_loss improved from 1.71758 to 1.65870, saving model to output/test_cls.hdf5
# Epoch 34/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 1.9410 - acc: 0.5772 - val_loss: 1.6061 - val_acc: 0.6121
#
# Epoch 00034: val_loss improved from 1.65870 to 1.60613, saving model to output/test_cls.hdf5
# Epoch 35/150
# 2443/2443 [==============================] - 0s 90us/step - loss: 1.8590 - acc: 0.5702 - val_loss: 1.5510 - val_acc: 0.6105
#
# Epoch 00035: val_loss improved from 1.60613 to 1.55098, saving model to output/test_cls.hdf5
# Epoch 36/150
# 2443/2443 [==============================] - 0s 90us/step - loss: 1.7894 - acc: 0.5677 - val_loss: 1.5053 - val_acc: 0.6105
#
# Epoch 00036: val_loss improved from 1.55098 to 1.50528, saving model to output/test_cls.hdf5
# Epoch 37/150
# 2443/2443 [==============================] - 0s 89us/step - loss: 1.7208 - acc: 0.5608 - val_loss: 1.4579 - val_acc: 0.6105
#
# Epoch 00037: val_loss improved from 1.50528 to 1.45789, saving model to output/test_cls.hdf5
# Epoch 38/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 1.6554 - acc: 0.5661 - val_loss: 1.4169 - val_acc: 0.6105
#
# Epoch 00038: val_loss improved from 1.45789 to 1.41692, saving model to output/test_cls.hdf5
# Epoch 39/150
# 2443/2443 [==============================] - 0s 90us/step - loss: 1.5885 - acc: 0.5722 - val_loss: 1.3738 - val_acc: 0.6105
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 0.0009000000427477062.
#
# Epoch 00039: val_loss improved from 1.41692 to 1.37385, saving model to output/test_cls.hdf5
# Epoch 40/150
# 2443/2443 [==============================] - 0s 90us/step - loss: 1.5319 - acc: 0.5837 - val_loss: 1.3398 - val_acc: 0.6105
#
# Epoch 00040: val_loss improved from 1.37385 to 1.33980, saving model to output/test_cls.hdf5
# Epoch 41/150
# 2443/2443 [==============================] - 0s 89us/step - loss: 1.4872 - acc: 0.5710 - val_loss: 1.3070 - val_acc: 0.6105
#
# Epoch 00041: val_loss improved from 1.33980 to 1.30698, saving model to output/test_cls.hdf5
# Epoch 42/150
# 2443/2443 [==============================] - 0s 95us/step - loss: 1.4354 - acc: 0.5989 - val_loss: 1.2746 - val_acc: 0.6137
#
# Epoch 00042: val_loss improved from 1.30698 to 1.27462, saving model to output/test_cls.hdf5
# Epoch 43/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 1.4005 - acc: 0.5792 - val_loss: 1.2434 - val_acc: 0.6088
#
# Epoch 00043: val_loss improved from 1.27462 to 1.24341, saving model to output/test_cls.hdf5
# Epoch 44/150
# 2443/2443 [==============================] - 0s 91us/step - loss: 1.3636 - acc: 0.5788 - val_loss: 1.2139 - val_acc: 0.6105
#
# Epoch 00044: val_loss improved from 1.24341 to 1.21388, saving model to output/test_cls.hdf5
# Epoch 45/150
# 2443/2443 [==============================] - 0s 92us/step - loss: 1.3217 - acc: 0.5878 - val_loss: 1.1895 - val_acc: 0.6105
#
# Epoch 00045: val_loss improved from 1.21388 to 1.18952, saving model to output/test_cls.hdf5
# Epoch 46/150
# 2443/2443 [==============================] - 0s 90us/step - loss: 1.2884 - acc: 0.5907 - val_loss: 1.1672 - val_acc: 0.6121
#
# Epoch 00046: val_loss improved from 1.18952 to 1.16723, saving model to output/test_cls.hdf5
# Epoch 47/150
# 2443/2443 [==============================] - 0s 86us/step - loss: 1.2551 - acc: 0.5829 - val_loss: 1.1436 - val_acc: 0.6105
#
# Epoch 00047: val_loss improved from 1.16723 to 1.14358, saving model to output/test_cls.hdf5
# Epoch 48/150
# 2443/2443 [==============================] - 0s 89us/step - loss: 1.2263 - acc: 0.5772 - val_loss: 1.1175 - val_acc: 0.6088
#
# Epoch 00048: val_loss improved from 1.14358 to 1.11746, saving model to output/test_cls.hdf5
# Epoch 49/150
# 2443/2443 [==============================] - 0s 87us/step - loss: 1.1924 - acc: 0.5833 - val_loss: 1.0938 - val_acc: 0.6154
#
# Epoch 00049: val_loss improved from 1.11746 to 1.09379, saving model to output/test_cls.hdf5
# Epoch 50/150
# 2443/2443 [==============================] - 0s 89us/step - loss: 1.1681 - acc: 0.5898 - val_loss: 1.0753 - val_acc: 0.6105
#
# Epoch 00050: val_loss improved from 1.09379 to 1.07526, saving model to output/test_cls.hdf5
# Epoch 51/150
# 2443/2443 [==============================] - 0s 94us/step - loss: 1.1429 - acc: 0.5788 - val_loss: 1.0569 - val_acc: 0.6105
#
# Epoch 00051: val_loss improved from 1.07526 to 1.05692, saving model to output/test_cls.hdf5
# Epoch 52/150
# 2443/2443 [==============================] - 0s 90us/step - loss: 1.1173 - acc: 0.5817 - val_loss: 1.0406 - val_acc: 0.6137
#
# Epoch 00052: val_loss improved from 1.05692 to 1.04060, saving model to output/test_cls.hdf5
# Epoch 53/150
# 2443/2443 [==============================] - 0s 89us/step - loss: 1.0941 - acc: 0.5841 - val_loss: 1.0223 - val_acc: 0.6105
#
# Epoch 00053: val_loss improved from 1.04060 to 1.02234, saving model to output/test_cls.hdf5
# Epoch 54/150
# 2443/2443 [==============================] - 0s 91us/step - loss: 1.0727 - acc: 0.5825 - val_loss: 1.0030 - val_acc: 0.6105
#
# Epoch 00054: val_loss improved from 1.02234 to 1.00305, saving model to output/test_cls.hdf5
# Epoch 55/150
# 2443/2443 [==============================] - 0s 90us/step - loss: 1.0483 - acc: 0.5882 - val_loss: 0.9882 - val_acc: 0.6137
#
# Epoch 00055: val_loss improved from 1.00305 to 0.98818, saving model to output/test_cls.hdf5
# Epoch 56/150
# 2443/2443 [==============================] - 0s 90us/step - loss: 1.0296 - acc: 0.5907 - val_loss: 0.9771 - val_acc: 0.6056
#
# Epoch 00056: val_loss improved from 0.98818 to 0.97713, saving model to output/test_cls.hdf5
# Epoch 57/150
# 2443/2443 [==============================] - 0s 93us/step - loss: 1.0172 - acc: 0.5784 - val_loss: 0.9540 - val_acc: 0.6137
#
# Epoch 00057: val_loss improved from 0.97713 to 0.95404, saving model to output/test_cls.hdf5
# Epoch 58/150
# 2443/2443 [==============================] - 0s 91us/step - loss: 0.9941 - acc: 0.5907 - val_loss: 0.9433 - val_acc: 0.6121
#
# Epoch 00058: val_loss improved from 0.95404 to 0.94330, saving model to output/test_cls.hdf5
# Epoch 59/150
# 2443/2443 [==============================] - 0s 91us/step - loss: 0.9803 - acc: 0.5845 - val_loss: 0.9310 - val_acc: 0.6187
#
# Epoch 00059: val_loss improved from 0.94330 to 0.93096, saving model to output/test_cls.hdf5
# Epoch 60/150
# 2443/2443 [==============================] - 0s 91us/step - loss: 0.9644 - acc: 0.5874 - val_loss: 0.9154 - val_acc: 0.6170
#
# Epoch 00060: val_loss improved from 0.93096 to 0.91537, saving model to output/test_cls.hdf5
# Epoch 61/150
# 2443/2443 [==============================] - 0s 90us/step - loss: 0.9479 - acc: 0.5939 - val_loss: 0.9011 - val_acc: 0.6154
#
# Epoch 00061: val_loss improved from 0.91537 to 0.90112, saving model to output/test_cls.hdf5
# Epoch 62/150
# 2443/2443 [==============================] - 0s 90us/step - loss: 0.9311 - acc: 0.5948 - val_loss: 0.8958 - val_acc: 0.6088
#
# Epoch 00062: val_loss improved from 0.90112 to 0.89581, saving model to output/test_cls.hdf5
# Epoch 63/150
# 2443/2443 [==============================] - 0s 89us/step - loss: 0.9205 - acc: 0.5944 - val_loss: 0.8790 - val_acc: 0.6088
#
# Epoch 00063: val_loss improved from 0.89581 to 0.87903, saving model to output/test_cls.hdf5
# Epoch 64/150
# 2443/2443 [==============================] - 0s 91us/step - loss: 0.9086 - acc: 0.5849 - val_loss: 0.8724 - val_acc: 0.6154
#
# Epoch 00064: val_loss improved from 0.87903 to 0.87237, saving model to output/test_cls.hdf5
# Epoch 65/150
# 2443/2443 [==============================] - 0s 91us/step - loss: 0.8954 - acc: 0.6038 - val_loss: 0.8706 - val_acc: 0.6219
#
# Epoch 00065: val_loss improved from 0.87237 to 0.87056, saving model to output/test_cls.hdf5
# Epoch 66/150
# 2443/2443 [==============================] - 0s 91us/step - loss: 0.8867 - acc: 0.5878 - val_loss: 0.8546 - val_acc: 0.6187
#
# Epoch 00066: val_loss improved from 0.87056 to 0.85465, saving model to output/test_cls.hdf5
# Epoch 67/150
# 2443/2443 [==============================] - 0s 92us/step - loss: 0.8741 - acc: 0.5886 - val_loss: 0.8459 - val_acc: 0.6072
#
# Epoch 00067: val_loss improved from 0.85465 to 0.84592, saving model to output/test_cls.hdf5
# Epoch 68/150
# 2443/2443 [==============================] - 0s 90us/step - loss: 0.8636 - acc: 0.5931 - val_loss: 0.8329 - val_acc: 0.6137
#
# Epoch 00068: val_loss improved from 0.84592 to 0.83292, saving model to output/test_cls.hdf5
# Epoch 69/150
# 2443/2443 [==============================] - 0s 91us/step - loss: 0.8547 - acc: 0.5931 - val_loss: 0.8443 - val_acc: 0.5859
#
# Epoch 00069: val_loss did not improve
# Epoch 70/150
# 2443/2443 [==============================] - 0s 90us/step - loss: 0.8490 - acc: 0.5948 - val_loss: 0.8203 - val_acc: 0.6154
#
# Epoch 00070: val_loss improved from 0.83292 to 0.82029, saving model to output/test_cls.hdf5
# Epoch 71/150
# 2443/2443 [==============================] - 0s 95us/step - loss: 0.8354 - acc: 0.5919 - val_loss: 0.8122 - val_acc: 0.6121
#
# Epoch 00071: val_loss improved from 0.82029 to 0.81224, saving model to output/test_cls.hdf5
# Epoch 72/150
# 2443/2443 [==============================] - 0s 86us/step - loss: 0.8268 - acc: 0.5972 - val_loss: 0.8061 - val_acc: 0.6088
#
# Epoch 00072: val_loss improved from 0.81224 to 0.80606, saving model to output/test_cls.hdf5
# Epoch 73/150
# 2443/2443 [==============================] - 0s 84us/step - loss: 0.8189 - acc: 0.5952 - val_loss: 0.8052 - val_acc: 0.6121
#
# Epoch 00073: val_loss improved from 0.80606 to 0.80518, saving model to output/test_cls.hdf5
# Epoch 74/150
# 2443/2443 [==============================] - 0s 85us/step - loss: 0.8149 - acc: 0.5948 - val_loss: 0.8013 - val_acc: 0.6170
#
# Epoch 00074: val_loss improved from 0.80518 to 0.80131, saving model to output/test_cls.hdf5
# Epoch 75/150
# 2443/2443 [==============================] - 0s 84us/step - loss: 0.8048 - acc: 0.6013 - val_loss: 0.7897 - val_acc: 0.6072
#
# Epoch 00075: val_loss improved from 0.80131 to 0.78967, saving model to output/test_cls.hdf5
# Epoch 76/150
# 2443/2443 [==============================] - 0s 87us/step - loss: 0.7998 - acc: 0.5919 - val_loss: 0.7832 - val_acc: 0.6170
#
# Epoch 00076: val_loss improved from 0.78967 to 0.78316, saving model to output/test_cls.hdf5
# Epoch 77/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 0.7907 - acc: 0.6005 - val_loss: 0.7779 - val_acc: 0.6088
#
# Epoch 00077: val_loss improved from 0.78316 to 0.77788, saving model to output/test_cls.hdf5
# Epoch 78/150
# 2443/2443 [==============================] - 0s 90us/step - loss: 0.7849 - acc: 0.6070 - val_loss: 0.7739 - val_acc: 0.6023
#
# Epoch 00078: val_loss improved from 0.77788 to 0.77386, saving model to output/test_cls.hdf5
# Epoch 79/150
# 2443/2443 [==============================] - 0s 87us/step - loss: 0.7802 - acc: 0.5931 - val_loss: 0.7751 - val_acc: 0.6039
#
# Epoch 00079: val_loss did not improve
# Epoch 80/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 0.7767 - acc: 0.6005 - val_loss: 0.7871 - val_acc: 0.5597
#
# Epoch 00080: val_loss did not improve
# Epoch 81/150
# 2443/2443 [==============================] - 0s 86us/step - loss: 0.7714 - acc: 0.5972 - val_loss: 0.7750 - val_acc: 0.6137
#
# Epoch 00081: val_loss did not improve
# Epoch 82/150
# 2443/2443 [==============================] - 0s 86us/step - loss: 0.7717 - acc: 0.5968 - val_loss: 0.7665 - val_acc: 0.6039
#
# Epoch 00082: val_loss improved from 0.77386 to 0.76653, saving model to output/test_cls.hdf5
# Epoch 83/150
# 2443/2443 [==============================] - 0s 86us/step - loss: 0.7621 - acc: 0.5927 - val_loss: 0.7557 - val_acc: 0.5957
#
# Epoch 00083: val_loss improved from 0.76653 to 0.75573, saving model to output/test_cls.hdf5
# Epoch 84/150
# 2443/2443 [==============================] - 0s 84us/step - loss: 0.7561 - acc: 0.5919 - val_loss: 0.7466 - val_acc: 0.6121
#
# Epoch 00084: val_loss improved from 0.75573 to 0.74663, saving model to output/test_cls.hdf5
# Epoch 85/150
# 2443/2443 [==============================] - 0s 84us/step - loss: 0.7520 - acc: 0.5964 - val_loss: 0.7536 - val_acc: 0.5957
#
# Epoch 00085: val_loss did not improve
# Epoch 86/150
# 2443/2443 [==============================] - 0s 85us/step - loss: 0.7472 - acc: 0.5976 - val_loss: 0.7461 - val_acc: 0.6023
#
# Epoch 00086: val_loss improved from 0.74663 to 0.74611, saving model to output/test_cls.hdf5
# Epoch 87/150
# 2443/2443 [==============================] - 0s 86us/step - loss: 0.7433 - acc: 0.5984 - val_loss: 0.7640 - val_acc: 0.5810
#
# Epoch 00087: val_loss did not improve
# Epoch 88/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 0.7460 - acc: 0.6058 - val_loss: 0.7688 - val_acc: 0.5466
#
# Epoch 00088: val_loss did not improve
# Epoch 89/150
# 2443/2443 [==============================] - 0s 87us/step - loss: 0.7400 - acc: 0.6013 - val_loss: 0.7347 - val_acc: 0.6170
#
# Epoch 00089: val_loss improved from 0.74611 to 0.73470, saving model to output/test_cls.hdf5
# Epoch 90/150
# 2443/2443 [==============================] - 0s 85us/step - loss: 0.7360 - acc: 0.5944 - val_loss: 0.7779 - val_acc: 0.5712
#
# Epoch 00090: val_loss did not improve
# Epoch 91/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 0.7458 - acc: 0.5919 - val_loss: 0.7313 - val_acc: 0.6007
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 0.0008100000384729356.
#
# Epoch 00091: val_loss improved from 0.73470 to 0.73128, saving model to output/test_cls.hdf5
# Epoch 92/150
# 2443/2443 [==============================] - 0s 89us/step - loss: 0.7340 - acc: 0.5984 - val_loss: 0.7336 - val_acc: 0.6007
#
# Epoch 00092: val_loss did not improve
# Epoch 93/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 0.7272 - acc: 0.6062 - val_loss: 0.7321 - val_acc: 0.6154
#
# Epoch 00093: val_loss did not improve
# Epoch 94/150
# 2443/2443 [==============================] - 0s 87us/step - loss: 0.7251 - acc: 0.6005 - val_loss: 0.7278 - val_acc: 0.6072
#
# Epoch 00094: val_loss improved from 0.73128 to 0.72776, saving model to output/test_cls.hdf5
# Epoch 95/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 0.7227 - acc: 0.5980 - val_loss: 0.7303 - val_acc: 0.5990
#
# Epoch 00095: val_loss did not improve
# Epoch 96/150
# 2443/2443 [==============================] - 0s 86us/step - loss: 0.7251 - acc: 0.5960 - val_loss: 0.7206 - val_acc: 0.6056
#
# Epoch 00096: val_loss improved from 0.72776 to 0.72061, saving model to output/test_cls.hdf5
# Epoch 97/150
# 2443/2443 [==============================] - 0s 87us/step - loss: 0.7173 - acc: 0.6062 - val_loss: 0.7404 - val_acc: 0.5827
#
# Epoch 00097: val_loss did not improve
# Epoch 98/150
# 2443/2443 [==============================] - 0s 90us/step - loss: 0.7208 - acc: 0.6120 - val_loss: 0.7599 - val_acc: 0.5368
#
# Epoch 00098: val_loss did not improve
# Epoch 99/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 0.7249 - acc: 0.6013 - val_loss: 0.7327 - val_acc: 0.5974
#
# Epoch 00099: val_loss did not improve
# Epoch 100/150
# 2443/2443 [==============================] - 0s 89us/step - loss: 0.7146 - acc: 0.6021 - val_loss: 0.7349 - val_acc: 0.5728
#
# Epoch 00100: val_loss did not improve
# Epoch 101/150
# 2443/2443 [==============================] - 0s 87us/step - loss: 0.7194 - acc: 0.5984 - val_loss: 0.7241 - val_acc: 0.5957
#
# Epoch 00101: val_loss did not improve
# Epoch 102/150
# 2443/2443 [==============================] - 0s 87us/step - loss: 0.7152 - acc: 0.6079 - val_loss: 0.7155 - val_acc: 0.6023
#
# Epoch 00102: val_loss improved from 0.72061 to 0.71554, saving model to output/test_cls.hdf5
# Epoch 103/150
# 2443/2443 [==============================] - 0s 85us/step - loss: 0.7090 - acc: 0.6058 - val_loss: 0.7649 - val_acc: 0.5254
#
# Epoch 00103: val_loss did not improve
# Epoch 104/150
# 2443/2443 [==============================] - 0s 86us/step - loss: 0.7175 - acc: 0.6009 - val_loss: 0.7274 - val_acc: 0.5974
#
# Epoch 00104: val_loss did not improve
# Epoch 105/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 0.7094 - acc: 0.6062 - val_loss: 0.7193 - val_acc: 0.5941
#
# Epoch 00105: val_loss did not improve
# Epoch 106/150
# 2443/2443 [==============================] - 0s 87us/step - loss: 0.7134 - acc: 0.6038 - val_loss: 0.7312 - val_acc: 0.6154
#
# Epoch 00106: val_loss did not improve
# Epoch 107/150
# 2443/2443 [==============================] - 0s 92us/step - loss: 0.7080 - acc: 0.6042 - val_loss: 0.7125 - val_acc: 0.6203
#
# Epoch 00107: val_loss improved from 0.71554 to 0.71248, saving model to output/test_cls.hdf5
# Epoch 108/150
# 2443/2443 [==============================] - 0s 90us/step - loss: 0.7074 - acc: 0.5989 - val_loss: 0.7248 - val_acc: 0.6187
#
# Epoch 00108: val_loss did not improve
# Epoch 109/150
# 2443/2443 [==============================] - 0s 87us/step - loss: 0.7082 - acc: 0.5993 - val_loss: 0.7345 - val_acc: 0.5663
#
# Epoch 00109: val_loss did not improve
# Epoch 110/150
# 2443/2443 [==============================] - 0s 91us/step - loss: 0.7093 - acc: 0.6009 - val_loss: 0.7095 - val_acc: 0.6219
#
# Epoch 00110: val_loss improved from 0.71248 to 0.70954, saving model to output/test_cls.hdf5
# Epoch 111/150
# 2443/2443 [==============================] - 0s 86us/step - loss: 0.7040 - acc: 0.6013 - val_loss: 0.7116 - val_acc: 0.6252
#
# Epoch 00111: val_loss did not improve
# Epoch 112/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 0.7033 - acc: 0.6054 - val_loss: 0.7091 - val_acc: 0.6137
#
# Epoch 00112: val_loss improved from 0.70954 to 0.70913, saving model to output/test_cls.hdf5
# Epoch 113/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 0.7019 - acc: 0.6091 - val_loss: 0.7167 - val_acc: 0.6137
#
# Epoch 00113: val_loss did not improve
# Epoch 114/150
# 2443/2443 [==============================] - 0s 89us/step - loss: 0.7043 - acc: 0.6079 - val_loss: 0.7140 - val_acc: 0.6154
#
# Epoch 00114: val_loss did not improve
# Epoch 115/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 0.7034 - acc: 0.5960 - val_loss: 0.7207 - val_acc: 0.6121
#
# Epoch 00115: val_loss did not improve
# Epoch 116/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 0.7059 - acc: 0.5993 - val_loss: 0.7079 - val_acc: 0.6187
#
# Epoch 00116: val_loss improved from 0.70913 to 0.70787, saving model to output/test_cls.hdf5
# Epoch 117/150
# 2443/2443 [==============================] - 0s 89us/step - loss: 0.6987 - acc: 0.6124 - val_loss: 0.7016 - val_acc: 0.5974
#
# Epoch 00117: val_loss improved from 0.70787 to 0.70156, saving model to output/test_cls.hdf5
# Epoch 118/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 0.7022 - acc: 0.6021 - val_loss: 0.7286 - val_acc: 0.5794
#
# Epoch 00118: val_loss did not improve
# Epoch 119/150
# 2443/2443 [==============================] - 0s 89us/step - loss: 0.7070 - acc: 0.6009 - val_loss: 0.7217 - val_acc: 0.5941
#
# Epoch 00119: val_loss did not improve
# Epoch 120/150
# 2443/2443 [==============================] - 0s 90us/step - loss: 0.7049 - acc: 0.5997 - val_loss: 0.7104 - val_acc: 0.6039
#
# Epoch 00120: val_loss did not improve
# Epoch 121/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 0.6983 - acc: 0.6050 - val_loss: 0.7152 - val_acc: 0.5892
#
# Epoch 00121: val_loss did not improve
# Epoch 122/150
# 2443/2443 [==============================] - 0s 92us/step - loss: 0.6995 - acc: 0.6042 - val_loss: 0.7106 - val_acc: 0.5974
#
# Epoch 00122: val_loss did not improve
# Epoch 123/150
# 2443/2443 [==============================] - 0s 91us/step - loss: 0.6987 - acc: 0.6099 - val_loss: 0.7329 - val_acc: 0.5450
#
# Epoch 00123: val_loss did not improve
# Epoch 124/150
# 2443/2443 [==============================] - 0s 100us/step - loss: 0.7033 - acc: 0.6021 - val_loss: 0.7161 - val_acc: 0.5777
#
# Epoch 00124: val_loss did not improve
# Epoch 125/150
# 2443/2443 [==============================] - 0s 95us/step - loss: 0.6978 - acc: 0.6017 - val_loss: 0.7124 - val_acc: 0.5925
#
# Epoch 00125: val_loss did not improve
# Epoch 126/150
# 2443/2443 [==============================] - 0s 92us/step - loss: 0.6992 - acc: 0.5952 - val_loss: 0.7056 - val_acc: 0.6137
#
# Epoch 00126: val_loss did not improve
# Epoch 127/150
# 2443/2443 [==============================] - 0s 96us/step - loss: 0.6912 - acc: 0.6115 - val_loss: 0.7153 - val_acc: 0.5859
#
# Epoch 00127: val_loss did not improve
# Epoch 128/150
# 2443/2443 [==============================] - 0s 96us/step - loss: 0.6967 - acc: 0.6009 - val_loss: 0.7234 - val_acc: 0.5925
#
# Epoch 00128: val_loss did not improve
# Epoch 129/150
# 2443/2443 [==============================] - 0s 91us/step - loss: 0.6976 - acc: 0.6066 - val_loss: 0.7142 - val_acc: 0.5876
#
# Epoch 00129: val_loss did not improve
# Epoch 130/150
# 2443/2443 [==============================] - 0s 86us/step - loss: 0.6979 - acc: 0.6029 - val_loss: 0.7236 - val_acc: 0.5859
#
# Epoch 00130: val_loss did not improve
# Epoch 131/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 0.6933 - acc: 0.6099 - val_loss: 0.7148 - val_acc: 0.6007
#
# Epoch 00131: val_loss did not improve
# Epoch 132/150
# 2443/2443 [==============================] - 0s 86us/step - loss: 0.6961 - acc: 0.6107 - val_loss: 0.7289 - val_acc: 0.5516
#
# Epoch 00132: val_loss did not improve
# Epoch 133/150
# 2443/2443 [==============================] - 0s 84us/step - loss: 0.6993 - acc: 0.6013 - val_loss: 0.7295 - val_acc: 0.5794
#
# Epoch 00133: val_loss did not improve
# Epoch 134/150
# 2443/2443 [==============================] - 0s 90us/step - loss: 0.6974 - acc: 0.6038 - val_loss: 0.7267 - val_acc: 0.5974
#
# Epoch 00134: val_loss did not improve
# Epoch 135/150
# 2443/2443 [==============================] - 0s 86us/step - loss: 0.7029 - acc: 0.6058 - val_loss: 0.7283 - val_acc: 0.5843
#
# Epoch 00135: val_loss did not improve
# Epoch 136/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 0.7053 - acc: 0.5976 - val_loss: 0.7341 - val_acc: 0.5434
#
# Epoch 00136: val_loss did not improve
# Epoch 137/150
# 2443/2443 [==============================] - 0s 87us/step - loss: 0.6946 - acc: 0.6046 - val_loss: 0.7455 - val_acc: 0.5548
#
# Epoch 00137: ReduceLROnPlateau reducing learning rate to 0.0007290000503417104.
#
# Epoch 00137: val_loss did not improve
# Epoch 138/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 0.6982 - acc: 0.6087 - val_loss: 0.7124 - val_acc: 0.5957
#
# Epoch 00138: val_loss did not improve
# Epoch 139/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 0.6956 - acc: 0.6079 - val_loss: 0.7070 - val_acc: 0.5843
#
# Epoch 00139: val_loss did not improve
# Epoch 140/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 0.6945 - acc: 0.6034 - val_loss: 0.7143 - val_acc: 0.5663
#
# Epoch 00140: val_loss did not improve
# Epoch 141/150
# 2443/2443 [==============================] - 0s 87us/step - loss: 0.6942 - acc: 0.6079 - val_loss: 0.6991 - val_acc: 0.6072
#
# Epoch 00141: val_loss improved from 0.70156 to 0.69907, saving model to output/test_cls.hdf5
# Epoch 142/150
# 2443/2443 [==============================] - 0s 93us/step - loss: 0.6921 - acc: 0.6046 - val_loss: 0.7324 - val_acc: 0.5745
#
# Epoch 00142: val_loss did not improve
# Epoch 143/150
# 2443/2443 [==============================] - 0s 97us/step - loss: 0.7051 - acc: 0.5886 - val_loss: 0.6996 - val_acc: 0.6007
#
# Epoch 00143: val_loss did not improve
# Epoch 144/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 0.6921 - acc: 0.6079 - val_loss: 0.7128 - val_acc: 0.5777
#
# Epoch 00144: val_loss did not improve
# Epoch 145/150
# 2443/2443 [==============================] - 0s 89us/step - loss: 0.6981 - acc: 0.5980 - val_loss: 0.6960 - val_acc: 0.5990
#
# Epoch 00145: val_loss improved from 0.69907 to 0.69598, saving model to output/test_cls.hdf5
# Epoch 146/150
# 2443/2443 [==============================] - 0s 99us/step - loss: 0.6844 - acc: 0.6120 - val_loss: 0.7084 - val_acc: 0.5990
#
# Epoch 00146: val_loss did not improve
# Epoch 147/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 0.6946 - acc: 0.6107 - val_loss: 0.7264 - val_acc: 0.5679
#
# Epoch 00147: val_loss did not improve
# Epoch 148/150
# 2443/2443 [==============================] - 0s 87us/step - loss: 0.6912 - acc: 0.6079 - val_loss: 0.7585 - val_acc: 0.5532
#
# Epoch 00148: val_loss did not improve
# Epoch 149/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 0.6980 - acc: 0.5886 - val_loss: 0.7284 - val_acc: 0.5794
#
# Epoch 00149: val_loss did not improve
# Epoch 150/150
# 2443/2443 [==============================] - 0s 87us/step - loss: 0.6997 - acc: 0.6095 - val_loss: 0.7096 - val_acc: 0.6088
#
# Epoch 00150: val_loss did not improve

# %%
plt.figure()
plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
plt.figure()
plt.plot(H.history['acc'])
plt.plot(H.history['val_acc'])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

pred = model.predict(np.array(X_test))
C = confusion_matrix([np.argmax(y) for y in Y_test], [np.argmax(y) for y in pred])

print(C/C.astype(np.float).sum(axis=1))

FROM = 0
TO = FROM + 100

original = Y_test[FROM:TO]
predicted = pred[FROM:TO]

print(original.shape)
print(predicted.shape)

plt.plot(original[:,1], color='black', label='Original Data')
plt.plot(predicted[:,1], color='blue', label='Predicted Data')
plt.legend(loc = 'best')
plt.title("Actual and Predicted from point {} to point {} of test set".format(FROM, TO))
plt.show()
# Out:
# [[0.11344538 0.56568365]
#  [0.11764706 0.92493298]]
# (100, 2)
# (100, 2)
