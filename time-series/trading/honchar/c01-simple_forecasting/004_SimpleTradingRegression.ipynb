# %%
import matplotlib.pylab as plt
import seaborn as sns
sns.despine
# Out:
# <function seaborn.utils.despine>

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.normalization import BatchNormalization
from keras.layers import Merge, LeakyReLU
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, CSVLogger, EarlyStopping
from keras.optimizers import RMSprop, Adam, SGD, Nadam
from keras.layers.advanced_activations import *
from keras.layers import Convolution1D, MaxPooling1D, AtrousConvolution1D
from keras.layers.recurrent import LSTM, GRU
from keras import regularizers
# Out:
# /anaconda3/envs/dlcv/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from preprocessing import shuffle_in_unison, create_Xt_Yt
# Out:
# [NbConvertApp] Converting notebook 001_Preprocessing.ipynb to python
# [NbConvertApp] Writing 3251 bytes to 001_Preprocessing.py

# %%
import pandas as pd

data = pd.read_csv("../datasets/apple/AAPL.csv")[::-1]
data.head()
data_changed = data.loc[:, 'Adj Close'].pct_change().tolist()

# %%
data = data.loc[:, 'Adj Close'].tolist()
plt.figure(figsize=(12, 8))
plt.plot(data)
plt.show()

# %%
plt.figure(figsize=(24, 8))
plt.plot(data_changed)
plt.show()

# %%
WINDOW = 30
EMB_SIZE = 1
STEP = 1
FORECAST = 5

# %%
# Create time window
X, Y = [], []
for i in range(0, len(data), STEP):
    try:
        x_i = data[i:i + WINDOW]
        y_i = data[i + WINDOW + FORECAST]

#         last_close = x_i[WINDOW - 1]
#         next_close = y_i

#         if last_close < next_close:
#             y_i = [1, 0]
#         else:
#             y_i = [0, 1]
    except Exception as e:
        print(e)
        break
        
    X.append(x_i)
    Y.append(y_i)
# Out:
# list index out of range

# %%
print(len(X))
print(len(X))
# Out:
# 3054
# 3054

# %%
import numpy as np
#X = [(np.array(x) - np.mean(x)) / np.std(x) for x in X]
X, Y = np.array(X), np.array(Y)

X_train, X_test, Y_train, Y_test = create_Xt_Yt(X, Y)

# %%
print(X.shape)
print(Y.shape)
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (3054, 30)
# (3054,)
# (2443, 30)
# (2443,)
# (611, 30)
# (611,)

# %%
model = Sequential()
model.add(Dense(64, input_dim=30, activity_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(Activation('relu'))

#model.add(Dropout(0.5))
model.add(Dense(16, activity_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Dense(1))
model.add(Activation('linear'))

opt = Nadam(lr=0.001)

reduce_lr = ReduceLROnPlateau(monitor='val_acc', factor=0.9, patience=25, min_lr=0.000001, verbose=1)
checkpointer = ModelCheckpoint('output/test_regr.hdf5', verbose=1, save_best_only=True)
model.compile(optimizer=opt, loss='mse', metrics=['accuracy'])

# %%
H = model.fit(X_train, Y_train, epochs=150, batch_size=128, verbose=1,
    validation_data=(X_test, Y_test), callbacks=[reduce_lr, checkpointer], shuffle=True)
# Out:
# Train on 2443 samples, validate on 611 samples
# Epoch 1/150
# 2443/2443 [==============================] - 1s 241us/step - loss: 145255.0652 - acc: 0.0000e+00 - val_loss: 845.6526 - val_acc: 0.0000e+00
#
# Epoch 00001: val_loss improved from inf to 845.65263, saving model to output/test_regr.hdf5
# Epoch 2/150
# 2443/2443 [==============================] - 0s 72us/step - loss: 46498.4866 - acc: 0.0000e+00 - val_loss: 272.7046 - val_acc: 0.0000e+00
#
# Epoch 00002: val_loss improved from 845.65263 to 272.70461, saving model to output/test_regr.hdf5
# Epoch 3/150
# 2443/2443 [==============================] - 0s 75us/step - loss: 14380.3059 - acc: 0.0000e+00 - val_loss: 124.3785 - val_acc: 0.0000e+00
#
# Epoch 00003: val_loss improved from 272.70461 to 124.37854, saving model to output/test_regr.hdf5
# Epoch 4/150
# 2443/2443 [==============================] - 0s 74us/step - loss: 6514.1886 - acc: 0.0000e+00 - val_loss: 85.0491 - val_acc: 0.0000e+00
#
# Epoch 00004: val_loss improved from 124.37854 to 85.04911, saving model to output/test_regr.hdf5
# Epoch 5/150
# 2443/2443 [==============================] - 0s 73us/step - loss: 4719.4474 - acc: 0.0000e+00 - val_loss: 73.0360 - val_acc: 0.0000e+00
#
# Epoch 00005: val_loss improved from 85.04911 to 73.03595, saving model to output/test_regr.hdf5
# Epoch 6/150
# 2443/2443 [==============================] - 0s 80us/step - loss: 4272.2269 - acc: 0.0000e+00 - val_loss: 67.9143 - val_acc: 0.0000e+00
#
# Epoch 00006: val_loss improved from 73.03595 to 67.91431, saving model to output/test_regr.hdf5
# Epoch 7/150
# 2443/2443 [==============================] - 0s 86us/step - loss: 4141.9556 - acc: 0.0000e+00 - val_loss: 65.4169 - val_acc: 0.0000e+00
#
# Epoch 00007: val_loss improved from 67.91431 to 65.41689, saving model to output/test_regr.hdf5
# Epoch 8/150
# 2443/2443 [==============================] - 0s 71us/step - loss: 4075.1554 - acc: 0.0000e+00 - val_loss: 64.3844 - val_acc: 0.0000e+00
#
# Epoch 00008: val_loss improved from 65.41689 to 64.38444, saving model to output/test_regr.hdf5
# Epoch 9/150
# 2443/2443 [==============================] - 0s 80us/step - loss: 4019.9095 - acc: 0.0000e+00 - val_loss: 63.4391 - val_acc: 0.0000e+00
#
# Epoch 00009: val_loss improved from 64.38444 to 63.43906, saving model to output/test_regr.hdf5
# Epoch 10/150
# 2443/2443 [==============================] - 0s 72us/step - loss: 3964.6336 - acc: 0.0000e+00 - val_loss: 63.0971 - val_acc: 0.0000e+00
#
# Epoch 00010: val_loss improved from 63.43906 to 63.09707, saving model to output/test_regr.hdf5
# Epoch 11/150
# 2443/2443 [==============================] - 0s 73us/step - loss: 3907.1736 - acc: 0.0000e+00 - val_loss: 62.1502 - val_acc: 0.0000e+00
#
# Epoch 00011: val_loss improved from 63.09707 to 62.15024, saving model to output/test_regr.hdf5
# Epoch 12/150
# 2443/2443 [==============================] - 0s 80us/step - loss: 3849.8568 - acc: 0.0000e+00 - val_loss: 61.5833 - val_acc: 0.0000e+00
#
# Epoch 00012: val_loss improved from 62.15024 to 61.58333, saving model to output/test_regr.hdf5
# Epoch 13/150
# 2443/2443 [==============================] - 0s 72us/step - loss: 3790.4729 - acc: 0.0000e+00 - val_loss: 61.3632 - val_acc: 0.0000e+00
#
# Epoch 00013: val_loss improved from 61.58333 to 61.36324, saving model to output/test_regr.hdf5
# Epoch 14/150
# 2443/2443 [==============================] - 0s 72us/step - loss: 3729.9499 - acc: 0.0000e+00 - val_loss: 60.7604 - val_acc: 0.0000e+00
#
# Epoch 00014: val_loss improved from 61.36324 to 60.76038, saving model to output/test_regr.hdf5
# Epoch 15/150
# 2443/2443 [==============================] - 0s 71us/step - loss: 3668.0562 - acc: 0.0000e+00 - val_loss: 60.0373 - val_acc: 0.0000e+00
#
# Epoch 00015: val_loss improved from 60.76038 to 60.03732, saving model to output/test_regr.hdf5
# Epoch 16/150
# 2443/2443 [==============================] - 0s 71us/step - loss: 3603.1002 - acc: 0.0000e+00 - val_loss: 59.8763 - val_acc: 0.0000e+00
#
# Epoch 00016: val_loss improved from 60.03732 to 59.87626, saving model to output/test_regr.hdf5
# Epoch 17/150
# 2443/2443 [==============================] - 0s 74us/step - loss: 3539.1721 - acc: 0.0000e+00 - val_loss: 59.2225 - val_acc: 0.0000e+00
#
# Epoch 00017: val_loss improved from 59.87626 to 59.22250, saving model to output/test_regr.hdf5
# Epoch 18/150
# 2443/2443 [==============================] - 0s 75us/step - loss: 3463.5877 - acc: 0.0000e+00 - val_loss: 59.0604 - val_acc: 0.0000e+00
#
# Epoch 00018: val_loss improved from 59.22250 to 59.06038, saving model to output/test_regr.hdf5
# Epoch 19/150
# 2443/2443 [==============================] - 0s 72us/step - loss: 3389.8375 - acc: 0.0000e+00 - val_loss: 58.6795 - val_acc: 0.0000e+00
#
# Epoch 00019: val_loss improved from 59.06038 to 58.67954, saving model to output/test_regr.hdf5
# Epoch 20/150
# 2443/2443 [==============================] - 0s 72us/step - loss: 3315.2069 - acc: 0.0000e+00 - val_loss: 58.4408 - val_acc: 0.0000e+00
#
# Epoch 00020: val_loss improved from 58.67954 to 58.44081, saving model to output/test_regr.hdf5
# Epoch 21/150
# 2443/2443 [==============================] - 0s 72us/step - loss: 3241.3410 - acc: 0.0000e+00 - val_loss: 58.8314 - val_acc: 0.0000e+00
#
# Epoch 00021: val_loss did not improve
# Epoch 22/150
# 2443/2443 [==============================] - 0s 80us/step - loss: 3157.0730 - acc: 0.0000e+00 - val_loss: 58.0135 - val_acc: 0.0000e+00
#
# Epoch 00022: val_loss improved from 58.44081 to 58.01352, saving model to output/test_regr.hdf5
# Epoch 23/150
# 2443/2443 [==============================] - 0s 79us/step - loss: 3074.2787 - acc: 0.0000e+00 - val_loss: 59.0918 - val_acc: 0.0000e+00
#
# Epoch 00023: val_loss did not improve
# Epoch 24/150
# 2443/2443 [==============================] - 0s 76us/step - loss: 2991.4163 - acc: 0.0000e+00 - val_loss: 58.5228 - val_acc: 0.0000e+00
#
# Epoch 00024: val_loss did not improve
# Epoch 25/150
# 2443/2443 [==============================] - 0s 79us/step - loss: 2904.3509 - acc: 0.0000e+00 - val_loss: 59.5069 - val_acc: 0.0000e+00
#
# Epoch 00025: val_loss did not improve
# Epoch 26/150
# 2443/2443 [==============================] - 0s 77us/step - loss: 2818.6499 - acc: 0.0000e+00 - val_loss: 58.6978 - val_acc: 0.0000e+00
#
# Epoch 00026: val_loss did not improve
# Epoch 27/150
# 2443/2443 [==============================] - 0s 78us/step - loss: 2729.3547 - acc: 0.0000e+00 - val_loss: 59.3557 - val_acc: 0.0000e+00
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0009000000427477062.
#
# Epoch 00027: val_loss did not improve
# Epoch 28/150
# 2443/2443 [==============================] - 0s 79us/step - loss: 2640.2254 - acc: 0.0000e+00 - val_loss: 60.7444 - val_acc: 0.0000e+00
#
# Epoch 00028: val_loss did not improve
# Epoch 29/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 2558.6898 - acc: 0.0000e+00 - val_loss: 60.6250 - val_acc: 0.0000e+00
#
# Epoch 00029: val_loss did not improve
# Epoch 30/150
# 2443/2443 [==============================] - 0s 79us/step - loss: 2478.3131 - acc: 0.0000e+00 - val_loss: 57.7140 - val_acc: 0.0000e+00
#
# Epoch 00030: val_loss improved from 58.01352 to 57.71399, saving model to output/test_regr.hdf5
# Epoch 31/150
# 2443/2443 [==============================] - 0s 79us/step - loss: 2398.6794 - acc: 0.0000e+00 - val_loss: 60.0341 - val_acc: 0.0000e+00
#
# Epoch 00031: val_loss did not improve
# Epoch 32/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 2319.3895 - acc: 0.0000e+00 - val_loss: 60.1940 - val_acc: 0.0000e+00
#
# Epoch 00032: val_loss did not improve
# Epoch 33/150
# 2443/2443 [==============================] - 0s 76us/step - loss: 2247.8874 - acc: 0.0000e+00 - val_loss: 60.8381 - val_acc: 0.0000e+00
#
# Epoch 00033: val_loss did not improve
# Epoch 34/150
# 2443/2443 [==============================] - 0s 78us/step - loss: 2160.6165 - acc: 0.0000e+00 - val_loss: 61.4110 - val_acc: 0.0000e+00
#
# Epoch 00034: val_loss did not improve
# Epoch 35/150
# 2443/2443 [==============================] - 0s 78us/step - loss: 2085.4376 - acc: 0.0000e+00 - val_loss: 62.9898 - val_acc: 0.0000e+00
#
# Epoch 00035: val_loss did not improve
# Epoch 36/150
# 2443/2443 [==============================] - 0s 80us/step - loss: 2009.8057 - acc: 0.0000e+00 - val_loss: 61.7067 - val_acc: 0.0000e+00
#
# Epoch 00036: val_loss did not improve
# Epoch 37/150
# 2443/2443 [==============================] - 0s 78us/step - loss: 1939.6582 - acc: 0.0000e+00 - val_loss: 63.6564 - val_acc: 0.0000e+00
#
# Epoch 00037: val_loss did not improve
# Epoch 38/150
# 2443/2443 [==============================] - 0s 79us/step - loss: 1861.8333 - acc: 0.0000e+00 - val_loss: 62.6495 - val_acc: 0.0000e+00
#
# Epoch 00038: val_loss did not improve
# Epoch 39/150
# 2443/2443 [==============================] - 0s 85us/step - loss: 1789.5844 - acc: 0.0000e+00 - val_loss: 62.5227 - val_acc: 0.0000e+00
#
# Epoch 00039: val_loss did not improve
# Epoch 40/150
# 2443/2443 [==============================] - 0s 78us/step - loss: 1715.5902 - acc: 0.0000e+00 - val_loss: 61.4974 - val_acc: 0.0000e+00
#
# Epoch 00040: val_loss did not improve
# Epoch 41/150
# 2443/2443 [==============================] - 0s 78us/step - loss: 1654.7830 - acc: 0.0000e+00 - val_loss: 65.0300 - val_acc: 0.0000e+00
#
# Epoch 00041: val_loss did not improve
# Epoch 42/150
# 2443/2443 [==============================] - 0s 81us/step - loss: 1590.0734 - acc: 0.0000e+00 - val_loss: 61.4083 - val_acc: 0.0000e+00
#
# Epoch 00042: val_loss did not improve
# Epoch 43/150
# 2443/2443 [==============================] - 0s 79us/step - loss: 1520.3509 - acc: 0.0000e+00 - val_loss: 60.2288 - val_acc: 0.0000e+00
#
# Epoch 00043: val_loss did not improve
# Epoch 44/150
# 2443/2443 [==============================] - 0s 79us/step - loss: 1461.1180 - acc: 0.0000e+00 - val_loss: 61.6103 - val_acc: 0.0000e+00
#
# Epoch 00044: val_loss did not improve
# Epoch 45/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 1396.2073 - acc: 0.0000e+00 - val_loss: 62.9093 - val_acc: 0.0000e+00
#
# Epoch 00045: val_loss did not improve
# Epoch 46/150
# 2443/2443 [==============================] - 0s 81us/step - loss: 1343.7495 - acc: 0.0000e+00 - val_loss: 63.1991 - val_acc: 0.0000e+00
#
# Epoch 00046: val_loss did not improve
# Epoch 47/150
# 2443/2443 [==============================] - 0s 85us/step - loss: 1276.8136 - acc: 0.0000e+00 - val_loss: 59.3078 - val_acc: 0.0000e+00
#
# Epoch 00047: val_loss did not improve
# Epoch 48/150
# 2443/2443 [==============================] - 0s 88us/step - loss: 1223.1433 - acc: 0.0000e+00 - val_loss: 61.4307 - val_acc: 0.0000e+00
#
# Epoch 00048: val_loss did not improve
# Epoch 49/150
# 2443/2443 [==============================] - 0s 91us/step - loss: 1169.6957 - acc: 0.0000e+00 - val_loss: 58.7042 - val_acc: 0.0000e+00
#
# Epoch 00049: val_loss did not improve
# Epoch 50/150
# 2443/2443 [==============================] - 0s 81us/step - loss: 1131.3986 - acc: 0.0000e+00 - val_loss: 59.8198 - val_acc: 0.0000e+00
#
# Epoch 00050: val_loss did not improve
# Epoch 51/150
# 2443/2443 [==============================] - 0s 98us/step - loss: 1071.9513 - acc: 0.0000e+00 - val_loss: 57.1561 - val_acc: 0.0000e+00
#
# Epoch 00051: val_loss improved from 57.71399 to 57.15611, saving model to output/test_regr.hdf5
# Epoch 52/150
# 2443/2443 [==============================] - 0s 116us/step - loss: 1033.8798 - acc: 0.0000e+00 - val_loss: 59.4643 - val_acc: 0.0000e+00
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.0008100000384729356.
#
# Epoch 00052: val_loss did not improve
# Epoch 53/150
# 2443/2443 [==============================] - 0s 105us/step - loss: 981.6662 - acc: 0.0000e+00 - val_loss: 57.8061 - val_acc: 0.0000e+00
#
# Epoch 00053: val_loss did not improve
# Epoch 54/150
# 2443/2443 [==============================] - 0s 92us/step - loss: 983.0327 - acc: 0.0000e+00 - val_loss: 60.4071 - val_acc: 0.0000e+00
#
# Epoch 00054: val_loss did not improve
# Epoch 55/150
# 2443/2443 [==============================] - 0s 100us/step - loss: 905.6168 - acc: 0.0000e+00 - val_loss: 58.8904 - val_acc: 0.0000e+00
#
# Epoch 00055: val_loss did not improve
# Epoch 56/150
# 2443/2443 [==============================] - 0s 100us/step - loss: 863.2233 - acc: 0.0000e+00 - val_loss: 60.2328 - val_acc: 0.0000e+00
#
# Epoch 00056: val_loss did not improve
# Epoch 57/150
# 2443/2443 [==============================] - 0s 95us/step - loss: 833.7079 - acc: 0.0000e+00 - val_loss: 59.5258 - val_acc: 0.0000e+00
#
# Epoch 00057: val_loss did not improve
# Epoch 58/150
# 2443/2443 [==============================] - 0s 97us/step - loss: 802.6714 - acc: 0.0000e+00 - val_loss: 58.5258 - val_acc: 0.0000e+00
#
# Epoch 00058: val_loss did not improve
# Epoch 59/150
# 2443/2443 [==============================] - 0s 95us/step - loss: 771.6419 - acc: 0.0000e+00 - val_loss: 59.9670 - val_acc: 0.0000e+00
#
# Epoch 00059: val_loss did not improve
# Epoch 60/150
# 2443/2443 [==============================] - 0s 92us/step - loss: 761.3457 - acc: 0.0000e+00 - val_loss: 57.1884 - val_acc: 0.0000e+00
#
# Epoch 00060: val_loss did not improve
# Epoch 61/150
# 2443/2443 [==============================] - 0s 91us/step - loss: 716.2775 - acc: 0.0000e+00 - val_loss: 62.1734 - val_acc: 0.0000e+00
#
# Epoch 00061: val_loss did not improve
# Epoch 62/150
# 2443/2443 [==============================] - 0s 95us/step - loss: 702.0004 - acc: 0.0000e+00 - val_loss: 56.1825 - val_acc: 0.0000e+00
#
# Epoch 00062: val_loss improved from 57.15611 to 56.18254, saving model to output/test_regr.hdf5
# Epoch 63/150
# 2443/2443 [==============================] - 0s 91us/step - loss: 688.0810 - acc: 0.0000e+00 - val_loss: 58.6547 - val_acc: 0.0000e+00
#
# Epoch 00063: val_loss did not improve
# Epoch 64/150
# 2443/2443 [==============================] - 0s 92us/step - loss: 649.2703 - acc: 0.0000e+00 - val_loss: 55.2518 - val_acc: 0.0000e+00
#
# Epoch 00064: val_loss improved from 56.18254 to 55.25184, saving model to output/test_regr.hdf5
# Epoch 65/150
# 2443/2443 [==============================] - 0s 84us/step - loss: 641.1951 - acc: 0.0000e+00 - val_loss: 57.1690 - val_acc: 0.0000e+00
#
# Epoch 00065: val_loss did not improve
# Epoch 66/150
# 2443/2443 [==============================] - 0s 81us/step - loss: 605.5253 - acc: 0.0000e+00 - val_loss: 55.8670 - val_acc: 0.0000e+00
#
# Epoch 00066: val_loss did not improve
# Epoch 67/150
# 2443/2443 [==============================] - 0s 81us/step - loss: 597.2445 - acc: 0.0000e+00 - val_loss: 50.9559 - val_acc: 0.0000e+00
#
# Epoch 00067: val_loss improved from 55.25184 to 50.95585, saving model to output/test_regr.hdf5
# Epoch 68/150
# 2443/2443 [==============================] - 0s 81us/step - loss: 584.9319 - acc: 0.0000e+00 - val_loss: 56.5259 - val_acc: 0.0000e+00
#
# Epoch 00068: val_loss did not improve
# Epoch 69/150
# 2443/2443 [==============================] - 0s 81us/step - loss: 553.0686 - acc: 0.0000e+00 - val_loss: 56.0331 - val_acc: 0.0000e+00
#
# Epoch 00069: val_loss did not improve
# Epoch 70/150
# 2443/2443 [==============================] - 0s 81us/step - loss: 535.3339 - acc: 0.0000e+00 - val_loss: 55.4773 - val_acc: 0.0000e+00
#
# Epoch 00070: val_loss did not improve
# Epoch 71/150
# 2443/2443 [==============================] - 0s 81us/step - loss: 516.1452 - acc: 0.0000e+00 - val_loss: 49.3487 - val_acc: 0.0000e+00
#
# Epoch 00071: val_loss improved from 50.95585 to 49.34872, saving model to output/test_regr.hdf5
# Epoch 72/150
# 2443/2443 [==============================] - 0s 81us/step - loss: 510.5131 - acc: 0.0000e+00 - val_loss: 51.0907 - val_acc: 0.0000e+00
#
# Epoch 00072: val_loss did not improve
# Epoch 73/150
# 2443/2443 [==============================] - 0s 84us/step - loss: 490.2076 - acc: 0.0000e+00 - val_loss: 52.5578 - val_acc: 0.0000e+00
#
# Epoch 00073: val_loss did not improve
# Epoch 74/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 476.7413 - acc: 0.0000e+00 - val_loss: 52.9210 - val_acc: 0.0000e+00
#
# Epoch 00074: val_loss did not improve
# Epoch 75/150
# 2443/2443 [==============================] - 0s 81us/step - loss: 462.1459 - acc: 0.0000e+00 - val_loss: 51.9811 - val_acc: 0.0000e+00
#
# Epoch 00075: val_loss did not improve
# Epoch 76/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 456.2615 - acc: 0.0000e+00 - val_loss: 50.3112 - val_acc: 0.0000e+00
#
# Epoch 00076: val_loss did not improve
# Epoch 77/150
# 2443/2443 [==============================] - 0s 81us/step - loss: 441.8161 - acc: 0.0000e+00 - val_loss: 51.7005 - val_acc: 0.0000e+00
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 0.0007290000503417104.
#
# Epoch 00077: val_loss did not improve
# Epoch 78/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 429.1799 - acc: 0.0000e+00 - val_loss: 49.1486 - val_acc: 0.0000e+00
#
# Epoch 00078: val_loss improved from 49.34872 to 49.14857, saving model to output/test_regr.hdf5
# Epoch 79/150
# 2443/2443 [==============================] - 0s 91us/step - loss: 423.7193 - acc: 0.0000e+00 - val_loss: 52.9522 - val_acc: 0.0000e+00
#
# Epoch 00079: val_loss did not improve
# Epoch 80/150
# 2443/2443 [==============================] - 0s 85us/step - loss: 407.1889 - acc: 0.0000e+00 - val_loss: 45.7511 - val_acc: 0.0000e+00
#
# Epoch 00080: val_loss improved from 49.14857 to 45.75110, saving model to output/test_regr.hdf5
# Epoch 81/150
# 2443/2443 [==============================] - 0s 86us/step - loss: 415.0965 - acc: 0.0000e+00 - val_loss: 49.5349 - val_acc: 0.0000e+00
#
# Epoch 00081: val_loss did not improve
# Epoch 82/150
# 2443/2443 [==============================] - 0s 80us/step - loss: 406.6416 - acc: 0.0000e+00 - val_loss: 47.5525 - val_acc: 0.0000e+00
#
# Epoch 00082: val_loss did not improve
# Epoch 83/150
# 2443/2443 [==============================] - 0s 79us/step - loss: 392.6479 - acc: 0.0000e+00 - val_loss: 51.4638 - val_acc: 0.0000e+00
#
# Epoch 00083: val_loss did not improve
# Epoch 84/150
# 2443/2443 [==============================] - 0s 79us/step - loss: 400.5520 - acc: 0.0000e+00 - val_loss: 49.1978 - val_acc: 0.0000e+00
#
# Epoch 00084: val_loss did not improve
# Epoch 85/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 362.5002 - acc: 0.0000e+00 - val_loss: 47.2425 - val_acc: 0.0000e+00
#
# Epoch 00085: val_loss did not improve
# Epoch 86/150
# 2443/2443 [==============================] - 0s 81us/step - loss: 362.2929 - acc: 0.0000e+00 - val_loss: 49.4738 - val_acc: 0.0000e+00
#
# Epoch 00086: val_loss did not improve
# Epoch 87/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 354.2326 - acc: 0.0000e+00 - val_loss: 48.1634 - val_acc: 0.0000e+00
#
# Epoch 00087: val_loss did not improve
# Epoch 88/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 358.9993 - acc: 0.0000e+00 - val_loss: 45.9222 - val_acc: 0.0000e+00
#
# Epoch 00088: val_loss did not improve
# Epoch 89/150
# 2443/2443 [==============================] - 0s 81us/step - loss: 344.6173 - acc: 0.0000e+00 - val_loss: 41.2800 - val_acc: 0.0000e+00
#
# Epoch 00089: val_loss improved from 45.75110 to 41.28005, saving model to output/test_regr.hdf5
# Epoch 90/150
# 2443/2443 [==============================] - 0s 79us/step - loss: 355.0915 - acc: 0.0000e+00 - val_loss: 48.0210 - val_acc: 0.0000e+00
#
# Epoch 00090: val_loss did not improve
# Epoch 91/150
# 2443/2443 [==============================] - 0s 79us/step - loss: 437.3170 - acc: 0.0000e+00 - val_loss: 44.9694 - val_acc: 0.0000e+00
#
# Epoch 00091: val_loss did not improve
# Epoch 92/150
# 2443/2443 [==============================] - 0s 80us/step - loss: 328.0839 - acc: 0.0000e+00 - val_loss: 44.4814 - val_acc: 0.0000e+00
#
# Epoch 00092: val_loss did not improve
# Epoch 93/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 308.9319 - acc: 0.0000e+00 - val_loss: 40.5237 - val_acc: 0.0000e+00
#
# Epoch 00093: val_loss improved from 41.28005 to 40.52365, saving model to output/test_regr.hdf5
# Epoch 94/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 300.8947 - acc: 0.0000e+00 - val_loss: 35.9280 - val_acc: 0.0000e+00
#
# Epoch 00094: val_loss improved from 40.52365 to 35.92805, saving model to output/test_regr.hdf5
# Epoch 95/150
# 2443/2443 [==============================] - 0s 81us/step - loss: 281.7601 - acc: 0.0000e+00 - val_loss: 32.4770 - val_acc: 0.0000e+00
#
# Epoch 00095: val_loss improved from 35.92805 to 32.47698, saving model to output/test_regr.hdf5
# Epoch 96/150
# 2443/2443 [==============================] - 0s 81us/step - loss: 272.2041 - acc: 0.0000e+00 - val_loss: 19.9054 - val_acc: 0.0000e+00
#
# Epoch 00096: val_loss improved from 32.47698 to 19.90539, saving model to output/test_regr.hdf5
# Epoch 97/150
# 2443/2443 [==============================] - 0s 89us/step - loss: 273.2246 - acc: 0.0000e+00 - val_loss: 18.8443 - val_acc: 0.0000e+00
#
# Epoch 00097: val_loss improved from 19.90539 to 18.84429, saving model to output/test_regr.hdf5
# Epoch 98/150
# 2443/2443 [==============================] - 0s 85us/step - loss: 265.0627 - acc: 0.0000e+00 - val_loss: 20.7875 - val_acc: 0.0000e+00
#
# Epoch 00098: val_loss did not improve
# Epoch 99/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 266.0330 - acc: 0.0000e+00 - val_loss: 22.1236 - val_acc: 0.0000e+00
#
# Epoch 00099: val_loss did not improve
# Epoch 100/150
# 2443/2443 [==============================] - 0s 81us/step - loss: 268.3662 - acc: 0.0000e+00 - val_loss: 26.0532 - val_acc: 0.0000e+00
#
# Epoch 00100: val_loss did not improve
# Epoch 101/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 246.8001 - acc: 0.0000e+00 - val_loss: 29.0018 - val_acc: 0.0000e+00
#
# Epoch 00101: val_loss did not improve
# Epoch 102/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 236.5263 - acc: 0.0000e+00 - val_loss: 30.8281 - val_acc: 0.0000e+00
#
# Epoch 00102: ReduceLROnPlateau reducing learning rate to 0.0006561000715009868.
#
# Epoch 00102: val_loss did not improve
# Epoch 103/150
# 2443/2443 [==============================] - 0s 87us/step - loss: 249.4514 - acc: 0.0000e+00 - val_loss: 28.3585 - val_acc: 0.0000e+00
#
# Epoch 00103: val_loss did not improve
# Epoch 104/150
# 2443/2443 [==============================] - 0s 85us/step - loss: 249.9040 - acc: 0.0000e+00 - val_loss: 35.7720 - val_acc: 0.0000e+00
#
# Epoch 00104: val_loss did not improve
# Epoch 105/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 226.5731 - acc: 0.0000e+00 - val_loss: 33.7019 - val_acc: 0.0000e+00
#
# Epoch 00105: val_loss did not improve
# Epoch 106/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 220.9642 - acc: 0.0000e+00 - val_loss: 35.2903 - val_acc: 0.0000e+00
#
# Epoch 00106: val_loss did not improve
# Epoch 107/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 220.3921 - acc: 0.0000e+00 - val_loss: 35.9137 - val_acc: 0.0000e+00
#
# Epoch 00107: val_loss did not improve
# Epoch 108/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 222.9237 - acc: 0.0000e+00 - val_loss: 39.3103 - val_acc: 0.0000e+00
#
# Epoch 00108: val_loss did not improve
# Epoch 109/150
# 2443/2443 [==============================] - 0s 91us/step - loss: 247.0836 - acc: 0.0000e+00 - val_loss: 36.6193 - val_acc: 0.0000e+00
#
# Epoch 00109: val_loss did not improve
# Epoch 110/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 211.3555 - acc: 0.0000e+00 - val_loss: 36.7638 - val_acc: 0.0000e+00
#
# Epoch 00110: val_loss did not improve
# Epoch 111/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 204.9132 - acc: 0.0000e+00 - val_loss: 43.8545 - val_acc: 0.0000e+00
#
# Epoch 00111: val_loss did not improve
# Epoch 112/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 199.7446 - acc: 0.0000e+00 - val_loss: 39.0853 - val_acc: 0.0000e+00
#
# Epoch 00112: val_loss did not improve
# Epoch 113/150
# 2443/2443 [==============================] - 0s 86us/step - loss: 222.7837 - acc: 0.0000e+00 - val_loss: 45.4168 - val_acc: 0.0000e+00
#
# Epoch 00113: val_loss did not improve
# Epoch 114/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 190.5260 - acc: 0.0000e+00 - val_loss: 46.8715 - val_acc: 0.0000e+00
#
# Epoch 00114: val_loss did not improve
# Epoch 115/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 193.1633 - acc: 0.0000e+00 - val_loss: 40.5867 - val_acc: 0.0000e+00
#
# Epoch 00115: val_loss did not improve
# Epoch 116/150
# 2443/2443 [==============================] - 0s 84us/step - loss: 197.2552 - acc: 0.0000e+00 - val_loss: 46.8613 - val_acc: 0.0000e+00
#
# Epoch 00116: val_loss did not improve
# Epoch 117/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 194.2094 - acc: 0.0000e+00 - val_loss: 36.5206 - val_acc: 0.0000e+00
#
# Epoch 00117: val_loss did not improve
# Epoch 118/150
# 2443/2443 [==============================] - 0s 84us/step - loss: 204.9089 - acc: 0.0000e+00 - val_loss: 50.6533 - val_acc: 0.0000e+00
#
# Epoch 00118: val_loss did not improve
# Epoch 119/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 181.1928 - acc: 0.0000e+00 - val_loss: 44.4131 - val_acc: 0.0000e+00
#
# Epoch 00119: val_loss did not improve
# Epoch 120/150
# 2443/2443 [==============================] - 0s 84us/step - loss: 173.5148 - acc: 0.0000e+00 - val_loss: 51.7556 - val_acc: 0.0000e+00
#
# Epoch 00120: val_loss did not improve
# Epoch 121/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 179.9354 - acc: 0.0000e+00 - val_loss: 47.7600 - val_acc: 0.0000e+00
#
# Epoch 00121: val_loss did not improve
# Epoch 122/150
# 2443/2443 [==============================] - 0s 85us/step - loss: 175.6583 - acc: 0.0000e+00 - val_loss: 43.5022 - val_acc: 0.0000e+00
#
# Epoch 00122: val_loss did not improve
# Epoch 123/150
# 2443/2443 [==============================] - 0s 84us/step - loss: 174.2102 - acc: 0.0000e+00 - val_loss: 38.3667 - val_acc: 0.0000e+00
#
# Epoch 00123: val_loss did not improve
# Epoch 124/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 202.1111 - acc: 0.0000e+00 - val_loss: 44.4416 - val_acc: 0.0000e+00
#
# Epoch 00124: val_loss did not improve
# Epoch 125/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 180.9783 - acc: 0.0000e+00 - val_loss: 54.9669 - val_acc: 0.0000e+00
#
# Epoch 00125: val_loss did not improve
# Epoch 126/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 189.7480 - acc: 0.0000e+00 - val_loss: 52.7038 - val_acc: 0.0000e+00
#
# Epoch 00126: val_loss did not improve
# Epoch 127/150
# 2443/2443 [==============================] - 0s 85us/step - loss: 188.6845 - acc: 0.0000e+00 - val_loss: 62.2139 - val_acc: 0.0000e+00
#
# Epoch 00127: ReduceLROnPlateau reducing learning rate to 0.0005904900433961303.
#
# Epoch 00127: val_loss did not improve
# Epoch 128/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 172.9202 - acc: 0.0000e+00 - val_loss: 52.8034 - val_acc: 0.0000e+00
#
# Epoch 00128: val_loss did not improve
# Epoch 129/150
# 2443/2443 [==============================] - 0s 84us/step - loss: 169.3088 - acc: 0.0000e+00 - val_loss: 61.4662 - val_acc: 0.0000e+00
#
# Epoch 00129: val_loss did not improve
# Epoch 130/150
# 2443/2443 [==============================] - 0s 98us/step - loss: 159.1824 - acc: 0.0000e+00 - val_loss: 51.8522 - val_acc: 0.0000e+00
#
# Epoch 00130: val_loss did not improve
# Epoch 131/150
# 2443/2443 [==============================] - 0s 84us/step - loss: 166.6611 - acc: 0.0000e+00 - val_loss: 62.0612 - val_acc: 0.0000e+00
#
# Epoch 00131: val_loss did not improve
# Epoch 132/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 155.7733 - acc: 0.0000e+00 - val_loss: 54.6916 - val_acc: 0.0000e+00
#
# Epoch 00132: val_loss did not improve
# Epoch 133/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 152.9258 - acc: 0.0000e+00 - val_loss: 64.8350 - val_acc: 0.0000e+00
#
# Epoch 00133: val_loss did not improve
# Epoch 134/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 162.4786 - acc: 0.0000e+00 - val_loss: 55.9543 - val_acc: 0.0000e+00
#
# Epoch 00134: val_loss did not improve
# Epoch 135/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 148.2865 - acc: 0.0000e+00 - val_loss: 63.0486 - val_acc: 0.0000e+00
#
# Epoch 00135: val_loss did not improve
# Epoch 136/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 153.7698 - acc: 0.0000e+00 - val_loss: 72.2115 - val_acc: 0.0000e+00
#
# Epoch 00136: val_loss did not improve
# Epoch 137/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 152.8344 - acc: 0.0000e+00 - val_loss: 78.6350 - val_acc: 0.0000e+00
#
# Epoch 00137: val_loss did not improve
# Epoch 138/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 164.2627 - acc: 0.0000e+00 - val_loss: 74.1417 - val_acc: 0.0000e+00
#
# Epoch 00138: val_loss did not improve
# Epoch 139/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 162.9867 - acc: 0.0000e+00 - val_loss: 54.6657 - val_acc: 0.0000e+00
#
# Epoch 00139: val_loss did not improve
# Epoch 140/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 159.8247 - acc: 0.0000e+00 - val_loss: 53.7282 - val_acc: 0.0000e+00
#
# Epoch 00140: val_loss did not improve
# Epoch 141/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 151.1322 - acc: 0.0000e+00 - val_loss: 48.2875 - val_acc: 0.0000e+00
#
# Epoch 00141: val_loss did not improve
# Epoch 142/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 159.3945 - acc: 0.0000e+00 - val_loss: 75.9536 - val_acc: 0.0000e+00
#
# Epoch 00142: val_loss did not improve
# Epoch 143/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 177.8069 - acc: 0.0000e+00 - val_loss: 66.4493 - val_acc: 0.0000e+00
#
# Epoch 00143: val_loss did not improve
# Epoch 144/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 144.1925 - acc: 0.0000e+00 - val_loss: 65.4543 - val_acc: 0.0000e+00
#
# Epoch 00144: val_loss did not improve
# Epoch 145/150
# 2443/2443 [==============================] - 0s 83us/step - loss: 137.5945 - acc: 0.0000e+00 - val_loss: 61.3563 - val_acc: 0.0000e+00
#
# Epoch 00145: val_loss did not improve
# Epoch 146/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 214.6194 - acc: 0.0000e+00 - val_loss: 55.1265 - val_acc: 0.0000e+00
#
# Epoch 00146: val_loss did not improve
# Epoch 147/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 146.5052 - acc: 0.0000e+00 - val_loss: 89.4256 - val_acc: 0.0000e+00
#
# Epoch 00147: val_loss did not improve
# Epoch 148/150
# 2443/2443 [==============================] - 0s 82us/step - loss: 145.9094 - acc: 0.0000e+00 - val_loss: 66.4746 - val_acc: 0.0000e+00
#
# Epoch 00148: val_loss did not improve
# Epoch 149/150
# 2443/2443 [==============================] - 0s 81us/step - loss: 148.7198 - acc: 0.0000e+00 - val_loss: 73.0549 - val_acc: 0.0000e+00
#
# Epoch 00149: val_loss did not improve
# Epoch 150/150
# 2443/2443 [==============================] - 0s 87us/step - loss: 137.8871 - acc: 0.0000e+00 - val_loss: 82.3484 - val_acc: 0.0000e+00
#
# Epoch 00150: val_loss did not improve

# %%
plt.figure()
plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
plt.figure()
plt.plot(H.history['acc'])
plt.plot(H.history['val_acc'])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

pred = model.predict(np.array(X_test))
C = confusion_matrix([np.argmax(y) for y in Y_test], [np.argmax(y) for y in pred])

print(C/C.astype(np.float).sum(axis=1))

FROM = 0
TO = FROM + 500

original = Y_test[0:100]
predicted = pred[0:100]

plt.plot(original, color='black', label='Original Data')
plt.plot(predicted, color='blue', label='Predicted Data')
plt.legend(loc = 'best')
plt.title("Actual and Predicted from point {} to point {} of test set".format(FROM, TO))
plt.show()
# Out:
# [[1.]]
